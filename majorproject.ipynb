# %%
# !pip install accelerate -U
# !pip install diffusers

# %%
# Load model directly
from transformers import AutoImageProcessor, AutoModelForVideoClassification

processor = AutoImageProcessor.from_pretrained("archit11/videomae-base-finetuned-fight-nofight-subset2")
model = AutoModelForVideoClassification.from_pretrained("archit11/videomae-base-finetuned-fight-nofight-subset2")
# Out:
# 2024-01-31 13:21:46.912948: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 13:21:46.913118: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 13:21:47.077668: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# preprocessor_config.json:   0%|          | 0.00/415 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/935 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/345M [00:00<?, ?B/s]

# %%
model
# Out:
# VideoMAEForVideoClassification(
#   (videomae): VideoMAEModel(
#     (embeddings): VideoMAEEmbeddings(
#       (patch_embeddings): VideoMAEPatchEmbeddings(
#         (projection): Conv3d(3, 768, kernel_size=(2, 16, 16), stride=(2, 16, 16))
#       )
#     )
#     (encoder): VideoMAEEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x VideoMAELayer(
#           (attention): VideoMAEAttention(
#             (attention): VideoMAESelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=False)
#               (key): Linear(in_features=768, out_features=768, bias=False)
#               (value): Linear(in_features=768, out_features=768, bias=False)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): VideoMAESelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): VideoMAEIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): VideoMAEOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# !pip install tensorflow
# !pip install evaluate
# !pip install pytorchvideo transformers evaluate -q
# !pip install hf_transfer

# %%
pip install hf_transfer

# %%
import evaluate
metric = evaluate.load("accuracy")
# Out:
# 2024-01-31 09:32:05.494412: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 09:32:05.494522: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 09:32:05.765243: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
model_ckpt = "MCG-NJU/videomae-base" # pre-trained model from which to fine-tune
batch_size = 4 # batch size for training and evaluation

# %% [markdown]
# Before we start, let's install the `pytorchvideo`, `transformers`, and `evaluate` libraries.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Then you need to install Git-LFS to upload your model checkpoints:

# %%
# !git config --global credential.helper store

# %%
import os

# os.environ["HF_ENDPOINT"] = "http://localhost:5564"
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

from huggingface_hub import HfApi, logging

# %%
from huggingface_hub import hf_hub_download


hf_dataset_identifier = "Pinwheel/ActsOfAgression"
filename = "xclip_fight.zip"
file_path = hf_hub_download(
    repo_id=hf_dataset_identifier, filename=filename, repo_type="dataset"
)
# Out:
# xclip_fight.zip:   0%|          | 0.00/12.3G [00:00<?, ?B/s]

# %% [markdown]
# Now, let's investigate what is inside the archive.

# %%
# !unzip -d . {file_path}
# Out:
# Archive:  /root/.cache/huggingface/hub/datasets--Pinwheel--ActsOfAgression/snapshots/8773376cc71070fbbffa4fc13128edabf5e57bf9/xclip_fight.zip
#    creating: ./xclip_fight/
#    creating: ./xclip_fight/val/
#    creating: ./xclip_fight/val/Fight/
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_1.avi
#   inflating: ./xclip_fight/val/Fight/0Ow4cotKOuw_0.avi
#   inflating: ./xclip_fight/val/Fight/0Ow4cotKOuw_1.avi
#   inflating: ./xclip_fight/val/Fight/0Ow4cotKOuw_2.avi
#   inflating: ./xclip_fight/val/Fight/0Ow4cotKOuw_3.avi
#   inflating: ./xclip_fight/val/Fight/0Ow4cotKOuw_4.avi
#   inflating: ./xclip_fight/val/Fight/1Kbw1bUw_0.avi
#   inflating: ./xclip_fight/val/Fight/1Kbw1bUw_1.avi
#   inflating: ./xclip_fight/val/Fight/1Kbw1bUw_2.avi
#   inflating: ./xclip_fight/val/Fight/1Kbw1bUw_3.avi
#   inflating: ./xclip_fight/val/Fight/1MVS2QPWbHc_0.avi
#   inflating: ./xclip_fight/val/Fight/1MVS2QPWbHc_1.avi
#   inflating: ./xclip_fight/val/Fight/1MVS2QPWbHc_2.avi
#   inflating: ./xclip_fight/val/Fight/1MVS2QPWbHc_3.avi
#   inflating: ./xclip_fight/val/Fight/1MVS2QPWbHc_4.avi
#   inflating: ./xclip_fight/val/Fight/1MVS2QPWbHc_5.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_0.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_1.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_2.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_3.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_4.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_5.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_6.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_7.avi
#   inflating: ./xclip_fight/val/Fight/39BFeYnbu-I_8.avi
#   inflating: ./xclip_fight/val/Fight/48J5lk4QcpE_0.avi
#   inflating: ./xclip_fight/val/Fight/48J5lk4QcpE_1.avi
#   inflating: ./xclip_fight/val/Fight/48J5lk4QcpE_2.avi
#   inflating: ./xclip_fight/val/Fight/48J5lk4QcpE_3.avi
#   inflating: ./xclip_fight/val/Fight/6Rl7q_kXYbg_0.avi
#   inflating: ./xclip_fight/val/Fight/6Rl7q_kXYbg_1.avi
#   inflating: ./xclip_fight/val/Fight/6Rl7q_kXYbg_2.avi
#   inflating: ./xclip_fight/val/Fight/6Rl7q_kXYbg_3.avi
#   inflating: ./xclip_fight/val/Fight/6Rl7q_kXYbg_4.avi
#   inflating: ./xclip_fight/val/Fight/6Rl7q_kXYbg_5.avi
#   inflating: ./xclip_fight/val/Fight/7gLKFV5voOg_0.avi
#   inflating: ./xclip_fight/val/Fight/7gLKFV5voOg_1.avi
#   inflating: ./xclip_fight/val/Fight/83d-16REC40_0.avi
#   inflating: ./xclip_fight/val/Fight/83d-16REC40_1.avi
#   inflating: ./xclip_fight/val/Fight/A7FCl8G35Cs_0.avi
#   inflating: ./xclip_fight/val/Fight/A7FCl8G35Cs_1.avi
#   inflating: ./xclip_fight/val/Fight/ASGGSDG_183.avi
#   inflating: ./xclip_fight/val/Fight/EFv961C5RgY_0.avi
#   inflating: ./xclip_fight/val/Fight/EFv961C5RgY_1.avi
#   inflating: ./xclip_fight/val/Fight/FXC43fACfPc_0.avi
#   inflating: ./xclip_fight/val/Fight/FXC43fACfPc_1.avi
#   inflating: ./xclip_fight/val/Fight/FXC43fACfPc_2.avi
#   inflating: ./xclip_fight/val/Fight/FXC43fACfPc_3.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_0.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_1.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_2.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_3.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_4.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_5.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_6.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_7.avi
#   inflating: ./xclip_fight/val/Fight/I-QiUMPTWNE_8.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_0.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_1.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_2.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_3.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_4.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_5.avi
#   inflating: ./xclip_fight/val/Fight/JECBfnp2ZXc_6.avi
#   inflating: ./xclip_fight/val/Fight/MxkTo5F-nvU_0.avi
#   inflating: ./xclip_fight/val/Fight/MxkTo5F-nvU_1.avi
#   inflating: ./xclip_fight/val/Fight/MxkTo5F-nvU_2.avi
#   inflating: ./xclip_fight/val/Fight/MxkTo5F-nvU_3.avi
#   inflating: ./xclip_fight/val/Fight/MxkTo5F-nvU_4.avi
#   inflating: ./xclip_fight/val/Fight/OvDMIkTb4XU_0.avi
#   inflating: ./xclip_fight/val/Fight/OvDMIkTb4XU_1.avi
#   inflating: ./xclip_fight/val/Fight/OvDMIkTb4XU_2.avi
#   inflating: ./xclip_fight/val/Fight/OvDMIkTb4XU_3.avi
#   inflating: ./xclip_fight/val/Fight/OvDMIkTb4XU_4.avi
#   inflating: ./xclip_fight/val/Fight/Q0v2MB0b_0.avi
#   inflating: ./xclip_fight/val/Fight/Qj3oZsaqNGE_0.avi
#   inflating: ./xclip_fight/val/Fight/Qj3oZsaqNGE_1.avi
#   inflating: ./xclip_fight/val/Fight/Qtcwz_K2Gvo_0.avi
#   inflating: ./xclip_fight/val/Fight/Qtcwz_K2Gvo_1.avi
#   inflating: ./xclip_fight/val/Fight/RETYTDF_523.avi
#   inflating: ./xclip_fight/val/Fight/RETYTDF_524.avi
#   inflating: ./xclip_fight/val/Fight/RIXaF_TkLlU_0.avi
#   inflating: ./xclip_fight/val/Fight/RIXaF_TkLlU_1.avi
#   inflating: ./xclip_fight/val/Fight/RIXaF_TkLlU_2.avi
#   inflating: ./xclip_fight/val/Fight/RIXaF_TkLlU_3.avi
#   inflating: ./xclip_fight/val/Fight/RIXaF_TkLlU_4.avi
#   inflating: ./xclip_fight/val/Fight/RIXaF_TkLlU_5.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_697.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_698.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_699.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_705.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_706.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_707.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_717.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_718.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_719.avi
#   inflating: ./xclip_fight/val/Fight/RTHTRS_720.avi
#   inflating: ./xclip_fight/val/Fight/Ry5c1PbcIa0_0.avi
#   inflating: ./xclip_fight/val/Fight/SDFDSSDF_972.avi
#   inflating: ./xclip_fight/val/Fight/SDFDSSDF_973.avi
#   inflating: ./xclip_fight/val/Fight/SDFDSSDF_974.avi
#   inflating: ./xclip_fight/val/Fight/SDFDSSDF_976.avi
#   inflating: ./xclip_fight/val/Fight/SDFDSSDF_977.avi
#   inflating: ./xclip_fight/val/Fight/SDFDSSDF_978.avi
#   inflating: ./xclip_fight/val/Fight/SJRnWfHAx_E_0.avi
#   inflating: ./xclip_fight/val/Fight/SJRnWfHAx_E_1.avi
#   inflating: ./xclip_fight/val/Fight/SJRnWfHAx_E_2.avi
#   inflating: ./xclip_fight/val/Fight/SJRnWfHAx_E_4.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1104.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1105.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1106.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1109.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1110.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1112.avi
#   inflating: ./xclip_fight/val/Fight/TYRFDVD_1113.avi
#   inflating: ./xclip_fight/val/Fight/Wq0BuA8GM84_0.avi
#   inflating: ./xclip_fight/val/Fight/XM0NI7ZmwWM_0.avi
#   inflating: ./xclip_fight/val/Fight/XM0NI7ZmwWM_1.avi
#   inflating: ./xclip_fight/val/Fight/XM0NI7ZmwWM_2.avi
#   inflating: ./xclip_fight/val/Fight/XM0NI7ZmwWM_3.avi
#   inflating: ./xclip_fight/val/Fight/Xcd0v-KhKL4_0.avi
#   inflating: ./xclip_fight/val/Fight/YDOJvzChqSg_0.avi
#   inflating: ./xclip_fight/val/Fight/YDOJvzChqSg_1.avi
#   inflating: ./xclip_fight/val/Fight/YDOJvzChqSg_2.avi
#   inflating: ./xclip_fight/val/Fight/YDOJvzChqSg_3.avi
#   inflating: ./xclip_fight/val/Fight/YDOJvzChqSg_4.avi
#   inflating: ./xclip_fight/val/Fight/bW2vHhYbzHM_0.avi
#   inflating: ./xclip_fight/val/Fight/e5Dmmply_0.avi
#   inflating: ./xclip_fight/val/Fight/e5Dmmply_1.avi
#   inflating: ./xclip_fight/val/Fight/e5Dmmply_2.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_0.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_1.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_2.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_3.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_4.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_5.avi
#   inflating: ./xclip_fight/val/Fight/etyiEs3j8x8_8.avi
#   inflating: ./xclip_fight/val/Fight/fbtEhNq5a6E_0.avi
#   inflating: ./xclip_fight/val/Fight/g-qjkePEXQA_0.avi
#   inflating: ./xclip_fight/val/Fight/g-qjkePEXQA_1.avi
#   inflating: ./xclip_fight/val/Fight/g-qjkePEXQA_2.avi
#   inflating: ./xclip_fight/val/Fight/g-qjkePEXQA_3.avi
#   inflating: ./xclip_fight/val/Fight/g6jdqkcdgqk_1.avi
#   inflating: ./xclip_fight/val/Fight/g6jdqkcdgqk_2.avi
#   inflating: ./xclip_fight/val/Fight/g6jdqkcdgqk_3.avi
#   inflating: ./xclip_fight/val/Fight/g6jdqkcdgqk_4.avi
#   inflating: ./xclip_fight/val/Fight/g6jdqkcdgqk_5.avi
#   inflating: ./xclip_fight/val/Fight/hytjfg_354.avi
#   inflating: ./xclip_fight/val/Fight/mwuiYEBdkJs_0.avi
#   inflating: ./xclip_fight/val/Fight/mwuiYEBdkJs_1.avi
#   inflating: ./xclip_fight/val/Fight/mwuiYEBdkJs_2.avi
#   inflating: ./xclip_fight/val/Fight/mwuiYEBdkJs_3.avi
#   inflating: ./xclip_fight/val/Fight/mwuiYEBdkJs_4.avi
#   inflating: ./xclip_fight/val/Fight/mwuiYEBdkJs_5.avi
#   inflating: ./xclip_fight/val/Fight/nVdn1krnTCQ_0.avi
#   inflating: ./xclip_fight/val/Fight/nVdn1krnTCQ_1.avi
#   inflating: ./xclip_fight/val/Fight/nVdn1krnTCQ_2.avi
#   inflating: ./xclip_fight/val/Fight/nVdn1krnTCQ_3.avi
#   inflating: ./xclip_fight/val/Fight/nVdn1krnTCQ_4.avi
#   inflating: ./xclip_fight/val/Fight/nVdn1krnTCQ_6.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_0.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_1.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_10.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_2.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_3.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_4.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_5.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_6.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_7.avi
#   inflating: ./xclip_fight/val/Fight/nuf-d5GugL0_9.avi
#   inflating: ./xclip_fight/val/Fight/qaAclucigpY_0.avi
#   inflating: ./xclip_fight/val/Fight/qaAclucigpY_1.avi
#   inflating: ./xclip_fight/val/Fight/qaAclucigpY_2.avi
#   inflating: ./xclip_fight/val/Fight/qaAclucigpY_3.avi
#   inflating: ./xclip_fight/val/Fight/tf_X7GtOGyE_0.avi
#   inflating: ./xclip_fight/val/Fight/tf_X7GtOGyE_1.avi
#   inflating: ./xclip_fight/val/Fight/tf_X7GtOGyE_2.avi
#   inflating: ./xclip_fight/val/Fight/tf_X7GtOGyE_3.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1039.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1040.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1048.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1049.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1050.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1053.avi
#   inflating: ./xclip_fight/val/Fight/trtrhrt_1054.avi
#   inflating: ./xclip_fight/val/Fight/v4dhdnsxiX4_0.avi
#   inflating: ./xclip_fight/val/Fight/v4dhdnsxiX4_1.avi
#   inflating: ./xclip_fight/val/Fight/v4dhdnsxiX4_2.avi
#   inflating: ./xclip_fight/val/Fight/v4dhdnsxiX4_3.avi
#   inflating: ./xclip_fight/val/Fight/xDjgfhGt-YA_0.avi
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_0.avi
#   inflating: ./xclip_fight/val/Fight/zOqs7Oh9oDM_2.avi
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_2.avi
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_3.avi
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_4.avi
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_5.avi
#   inflating: ./xclip_fight/val/Fight/y_vX9FtjLaQ_6.avi
#   inflating: ./xclip_fight/val/Fight/zOqs7Oh9oDM_0.avi
#   inflating: ./xclip_fight/val/Fight/zOqs7Oh9oDM_1.avi
#   inflating: ./xclip_fight/val/Fight/zOqs7Oh9oDM_3.avi
#    creating: ./xclip_fight/val/No Fight/
#   inflating: ./xclip_fight/val/No Fight/10uSOcwS_0.avi
#   inflating: ./xclip_fight/val/No Fight/1AURh0Wj_0.avi
#   inflating: ./xclip_fight/val/No Fight/1MVS2QPWbHc_0.avi
#   inflating: ./xclip_fight/val/No Fight/1MVS2QPWbHc_1.avi
#   inflating: ./xclip_fight/val/No Fight/1W8hsVvyKt4_0.avi
#   inflating: ./xclip_fight/val/No Fight/1W8hsVvyKt4_1.avi
#   inflating: ./xclip_fight/val/No Fight/1W8hsVvyKt4_2.avi
#   inflating: ./xclip_fight/val/No Fight/1W8hsVvyKt4_3.avi
#   inflating: ./xclip_fight/val/No Fight/2lrARl7utL4_0.avi
#   inflating: ./xclip_fight/val/No Fight/2lrARl7utL4_1.avi
#   inflating: ./xclip_fight/val/No Fight/2lrARl7utL4_2.avi
#   inflating: ./xclip_fight/val/No Fight/2qFnVnnZ_0.avi
#   inflating: ./xclip_fight/val/No Fight/32wXo9Dt_0.avi
#   inflating: ./xclip_fight/val/No Fight/39BFeYnbu-I_0.avi
#   inflating: ./xclip_fight/val/No Fight/4I1DGWsh_0.avi
#   inflating: ./xclip_fight/val/No Fight/4p2iGvo8_0.avi
#   inflating: ./xclip_fight/val/No Fight/66U2c3YMjOI_0.avi
#   inflating: ./xclip_fight/val/No Fight/66U2c3YMjOI_1.avi
#   inflating: ./xclip_fight/val/No Fight/6Rl7q_kXYbg_0.avi
#   inflating: ./xclip_fight/val/No Fight/6doZoiaG9PM_0.avi
#   inflating: ./xclip_fight/val/No Fight/6doZoiaG9PM_1.avi
#   inflating: ./xclip_fight/val/No Fight/6doZoiaG9PM_2.avi
#   inflating: ./xclip_fight/val/No Fight/6doZoiaG9PM_3.avi
#   inflating: ./xclip_fight/val/No Fight/7emxm3za_0.avi
#   inflating: ./xclip_fight/val/No Fight/7gLKFV5voOg_0.avi
#   inflating: ./xclip_fight/val/No Fight/8SmT9rE9_0.avi
#   inflating: ./xclip_fight/val/No Fight/8m3onRfr_0.avi
#   inflating: ./xclip_fight/val/No Fight/8s3rES1a_0.avi
#   inflating: ./xclip_fight/val/No Fight/8tWVjrUW_0.avi
#   inflating: ./xclip_fight/val/No Fight/9JxNZtUK_0.avi
#   inflating: ./xclip_fight/val/No Fight/9kly-mpQczg_0.avi
#   inflating: ./xclip_fight/val/No Fight/9kly-mpQczg_1.avi
#   inflating: ./xclip_fight/val/No Fight/A7FCl8G35Cs_0.avi
#   inflating: ./xclip_fight/val/No Fight/A7FCl8G35Cs_1.avi
#   inflating: ./xclip_fight/val/No Fight/Assault006_x264_0.avi
#   inflating: ./xclip_fight/val/No Fight/Assault006_x264_1.avi
#   inflating: ./xclip_fight/val/No Fight/BOnEkkm1_0.avi
#   inflating: ./xclip_fight/val/No Fight/Bp3wCVsS_0.avi
#   inflating: ./xclip_fight/val/No Fight/BySljls4_0.avi
#   inflating: ./xclip_fight/val/No Fight/CrBTbDcb_0.avi
#   inflating: ./xclip_fight/val/No Fight/Cw0HuNI5_0.avi
#   inflating: ./xclip_fight/val/No Fight/DeCoZoey_0.avi
#   inflating: ./xclip_fight/val/No Fight/E9SvEiNt_0.avi
#   inflating: ./xclip_fight/val/No Fight/EB08Cq4t_0.avi
#   inflating: ./xclip_fight/val/No Fight/EFv961C5RgY_0.avi
#   inflating: ./xclip_fight/val/No Fight/F6kgeh23_0.avi
#   inflating: ./xclip_fight/val/No Fight/Fds7C6sp_0.avi
#   inflating: ./xclip_fight/val/No Fight/FpDZIe2z_0.avi
#   inflating: ./xclip_fight/val/No Fight/Fwhi4UNI_0.avi
#   inflating: ./xclip_fight/val/No Fight/GCgD8AkV_0.avi
#   inflating: ./xclip_fight/val/No Fight/GXvqyqYi_0.avi
#   inflating: ./xclip_fight/val/No Fight/GYvqfFzN_0.avi
#   inflating: ./xclip_fight/val/No Fight/I-QiUMPTWNE_0.avi
#   inflating: ./xclip_fight/val/No Fight/I-QiUMPTWNE_1.avi
#   inflating: ./xclip_fight/val/No Fight/I-QiUMPTWNE_2.avi
#   inflating: ./xclip_fight/val/No Fight/I3rTHE3L_0.avi
#   inflating: ./xclip_fight/val/No Fight/I9OYGpUd_0.avi
#   inflating: ./xclip_fight/val/No Fight/IMA4zYs83Lo_0.avi
#   inflating: ./xclip_fight/val/No Fight/IvimSdBV_0.avi
#   inflating: ./xclip_fight/val/No Fight/JECBfnp2ZXc_0.avi
#   inflating: ./xclip_fight/val/No Fight/JECBfnp2ZXc_1.avi
#   inflating: ./xclip_fight/val/No Fight/JECBfnp2ZXc_2.avi
#   inflating: ./xclip_fight/val/No Fight/JOMXfA1R_0.avi
#   inflating: ./xclip_fight/val/No Fight/K4qpMWJS_0.avi
#   inflating: ./xclip_fight/val/No Fight/LKdiIccO_0.avi
#   inflating: ./xclip_fight/val/No Fight/LoQZojhn_0.avi
#   inflating: ./xclip_fight/val/No Fight/LruY67tu_0.avi
#   inflating: ./xclip_fight/val/No Fight/LtfqEsod_0.avi
#   inflating: ./xclip_fight/val/No Fight/MrEU15Ug_0.avi
#   inflating: ./xclip_fight/val/No Fight/MxkTo5F-nvU_0.avi
#   inflating: ./xclip_fight/val/No Fight/N8M1mmW9_0.avi
#   inflating: ./xclip_fight/val/No Fight/NQpYodM6_0.avi
#   inflating: ./xclip_fight/val/No Fight/NW4ndzCa_0.avi
#   inflating: ./xclip_fight/val/No Fight/NWIc3Yat_0.avi
#   inflating: ./xclip_fight/val/No Fight/NWqRgoGh_0.avi
#   inflating: ./xclip_fight/val/No Fight/NYvOWjLU_0.avi
#   inflating: ./xclip_fight/val/No Fight/NeyOxUHJ_0.avi
#   inflating: ./xclip_fight/val/No Fight/Nlopikk0zhE_0.avi
#   inflating: ./xclip_fight/val/No Fight/NnUOjff0_0.avi
#   inflating: ./xclip_fight/val/No Fight/NoUdd8wq_0.avi
#   inflating: ./xclip_fight/val/No Fight/O2rd3LTv_0.avi
#   inflating: ./xclip_fight/val/No Fight/Ob0YCDgS_0.avi
#   inflating: ./xclip_fight/val/No Fight/PL8idmS7_0.avi
#   inflating: ./xclip_fight/val/No Fight/PNgE-OKjhgU_0.avi
#   inflating: ./xclip_fight/val/No Fight/PNgE-OKjhgU_1.avi
#   inflating: ./xclip_fight/val/No Fight/PaTrwJbs_0.avi
#   inflating: ./xclip_fight/val/No Fight/QRJFLxqK_0.avi
#   inflating: ./xclip_fight/val/No Fight/Qj3oZsaqNGE_0.avi
#   inflating: ./xclip_fight/val/No Fight/RIXaF_TkLlU_0.avi
#   inflating: ./xclip_fight/val/No Fight/RIXaF_TkLlU_1.avi
#   inflating: ./xclip_fight/val/No Fight/RIXaF_TkLlU_2.avi
#   inflating: ./xclip_fight/val/No Fight/RQt37bnC_0.avi
#   inflating: ./xclip_fight/val/No Fight/Ry5c1PbcIa0_0.avi
#   inflating: ./xclip_fight/val/No Fight/S8jXc3sP_0.avi
#   inflating: ./xclip_fight/val/No Fight/SJRnWfHAx_E_0.avi
#   inflating: ./xclip_fight/val/No Fight/SJRnWfHAx_E_1.avi
#   inflating: ./xclip_fight/val/No Fight/SJRnWfHAx_E_2.avi
#   inflating: ./xclip_fight/val/No Fight/TP6mtOzL_0.avi
#   inflating: ./xclip_fight/val/No Fight/UoS3KEYq_0.avi
#   inflating: ./xclip_fight/val/No Fight/VF8M3gXp_0.avi
#   inflating: ./xclip_fight/val/No Fight/VGKvz9qZ_0.avi
#   inflating: ./xclip_fight/val/No Fight/VIPpAkyG_0.avi
#   inflating: ./xclip_fight/val/No Fight/VTOPSZvF_0.avi
#   inflating: ./xclip_fight/val/No Fight/VVQBImyG_0.avi
#   inflating: ./xclip_fight/val/No Fight/VtIQbKvy_0.avi
#   inflating: ./xclip_fight/val/No Fight/VzHfmJeI_0.avi
#   inflating: ./xclip_fight/val/No Fight/WPXtCPPS_0.avi
#   inflating: ./xclip_fight/val/No Fight/Wq0BuA8GM84_0.avi
#   inflating: ./xclip_fight/val/No Fight/Wq0BuA8GM84_1.avi
#   inflating: ./xclip_fight/val/No Fight/Xcd0v-KhKL4_0.avi
#   inflating: ./xclip_fight/val/No Fight/YDOJvzChqSg_0.avi
#   inflating: ./xclip_fight/val/No Fight/YL1qlr23_0.avi
#   inflating: ./xclip_fight/val/No Fight/YYCGcBuE_0.avi
#   inflating: ./xclip_fight/val/No Fight/Yf55ftZR_0.avi
#   inflating: ./xclip_fight/val/No Fight/Yma07mlW_0.avi
#   inflating: ./xclip_fight/val/No Fight/YukOkfIj_0.avi
#   inflating: ./xclip_fight/val/No Fight/ZCUy99AN_0.avi
#   inflating: ./xclip_fight/val/No Fight/ZCa5f4yq_0.avi
#   inflating: ./xclip_fight/val/No Fight/ZwhC7Kyg_0.avi
#   inflating: ./xclip_fight/val/No Fight/aZxUVVqk_0.avi
#   inflating: ./xclip_fight/val/No Fight/bW2vHhYbzHM_0.avi
#   inflating: ./xclip_fight/val/No Fight/bW2vHhYbzHM_1.avi
#   inflating: ./xclip_fight/val/No Fight/cpFWuHXF_0.avi
#   inflating: ./xclip_fight/val/No Fight/cw8fPfUL_0.avi
#   inflating: ./xclip_fight/val/No Fight/e8jli13nLaM_0.avi
#   inflating: ./xclip_fight/val/No Fight/eb4Oant1_0.avi
#   inflating: ./xclip_fight/val/No Fight/egQvmVL2_0.avi
#   inflating: ./xclip_fight/val/No Fight/etyiEs3j8x8_0.avi
#   inflating: ./xclip_fight/val/No Fight/etyiEs3j8x8_1.avi
#   inflating: ./xclip_fight/val/No Fight/etyiEs3j8x8_2.avi
#   inflating: ./xclip_fight/val/No Fight/fGyFpyjd_0.avi
#   inflating: ./xclip_fight/val/No Fight/fO2vb61DcUk_0.avi
#   inflating: ./xclip_fight/val/No Fight/fO2vb61DcUk_1.avi
#   inflating: ./xclip_fight/val/No Fight/g7fqR4gn_0.avi
#   inflating: ./xclip_fight/val/No Fight/g8SVNUCm_0.avi
#   inflating: ./xclip_fight/val/No Fight/gJV3TuKF_0.avi
#   inflating: ./xclip_fight/val/No Fight/iE9hzgQD_0.avi
#   inflating: ./xclip_fight/val/No Fight/iJ5Q1tar_0.avi
#   inflating: ./xclip_fight/val/No Fight/jpYrguiW_0.avi
#   inflating: ./xclip_fight/val/No Fight/kApoSGPK_0.avi
#   inflating: ./xclip_fight/val/No Fight/kMgCk8Ku_0.avi
#   inflating: ./xclip_fight/val/No Fight/l82NDOvk_0.avi
#   inflating: ./xclip_fight/val/No Fight/mwuiYEBdkJs_0.avi
#   inflating: ./xclip_fight/val/No Fight/mwuiYEBdkJs_1.avi
#   inflating: ./xclip_fight/val/No Fight/myaBOqJ3_0.avi
#   inflating: ./xclip_fight/val/No Fight/nTsOksk7_0.avi
#   inflating: ./xclip_fight/val/No Fight/nVdn1krnTCQ_0.avi
#   inflating: ./xclip_fight/val/No Fight/nVdn1krnTCQ_1.avi
#   inflating: ./xclip_fight/val/No Fight/nVdn1krnTCQ_2.avi
#   inflating: ./xclip_fight/val/No Fight/ngv36FBY_0.avi
#   inflating: ./xclip_fight/val/No Fight/nuf-d5GugL0_0.avi
#   inflating: ./xclip_fight/val/No Fight/nuf-d5GugL0_1.avi
#   inflating: ./xclip_fight/val/No Fight/nuf-d5GugL0_2.avi
#   inflating: ./xclip_fight/val/No Fight/oXeSTCLT_0.avi
#   inflating: ./xclip_fight/val/No Fight/ojZVUz7i_0.avi
#   inflating: ./xclip_fight/val/No Fight/q4jlVJRb_0.avi
#   inflating: ./xclip_fight/val/No Fight/qFfqTQm0_0.avi
#   inflating: ./xclip_fight/val/No Fight/qaAclucigpY_0.avi
#   inflating: ./xclip_fight/val/No Fight/qaAclucigpY_1.avi
#   inflating: ./xclip_fight/val/No Fight/qaAclucigpY_2.avi
#   inflating: ./xclip_fight/val/No Fight/qyRJeYN5_0.avi
#   inflating: ./xclip_fight/val/No Fight/r0mVR4J6_0.avi
#   inflating: ./xclip_fight/val/No Fight/rJbh1niy_0.avi
#   inflating: ./xclip_fight/val/No Fight/rtSWit6k_0.avi
#   inflating: ./xclip_fight/val/No Fight/rwg8hp5X_0.avi
#   inflating: ./xclip_fight/val/No Fight/scznszmE_0.avi
#   inflating: ./xclip_fight/val/No Fight/tSk5CEXB_0.avi
#   inflating: ./xclip_fight/val/No Fight/tf_X7GtOGyE_0.avi
#   inflating: ./xclip_fight/val/No Fight/tf_X7GtOGyE_1.avi
#   inflating: ./xclip_fight/val/No Fight/tf_X7GtOGyE_2.avi
#   inflating: ./xclip_fight/val/No Fight/tivF4CAg_0.avi
#   inflating: ./xclip_fight/val/No Fight/twBrsDhF_0.avi
#   inflating: ./xclip_fight/val/No Fight/u-VcErKk6Qs_0.avi
#   inflating: ./xclip_fight/val/No Fight/uZLLdl2P_0.avi
#   inflating: ./xclip_fight/val/No Fight/utRmPckr_0.avi
#   inflating: ./xclip_fight/val/No Fight/v1Sb6NhU_0.avi
#   inflating: ./xclip_fight/val/No Fight/v4dhdnsxiX4_0.avi
#   inflating: ./xclip_fight/val/No Fight/v4dhdnsxiX4_1.avi
#   inflating: ./xclip_fight/val/No Fight/v4dhdnsxiX4_2.avi
#   inflating: ./xclip_fight/val/No Fight/vAV3vIGr_0.avi
#   inflating: ./xclip_fight/val/No Fight/vDeu44Su_0.avi
#   inflating: ./xclip_fight/val/No Fight/vKUjLaXO_0.avi
#   inflating: ./xclip_fight/val/No Fight/vXGRa5D6_0.avi
#   inflating: ./xclip_fight/val/No Fight/w6VytllR_0.avi
#   inflating: ./xclip_fight/val/No Fight/wMcODEtzJIA_0.avi
#   inflating: ./xclip_fight/val/No Fight/wMcODEtzJIA_1.avi
#   inflating: ./xclip_fight/val/No Fight/wyLoweAn_9Q_0.avi
#   inflating: ./xclip_fight/val/No Fight/wyLoweAn_9Q_1.avi
#   inflating: ./xclip_fight/val/No Fight/xRbCHA5YTi8_0.avi
#   inflating: ./xclip_fight/val/No Fight/xV69l7Vj_0.avi
#   inflating: ./xclip_fight/val/No Fight/y2pGPMqikJg_0.avi
#   inflating: ./xclip_fight/val/No Fight/y2pGPMqikJg_1.avi
#   inflating: ./xclip_fight/val/No Fight/yFaADLZw_0.avi
#   inflating: ./xclip_fight/val/No Fight/yN11pFfP_0.avi
#   inflating: ./xclip_fight/val/No Fight/zGBzk5SeJOw_0.avi
#   inflating: ./xclip_fight/val/No Fight/zGBzk5SeJOw_1.avi
#   inflating: ./xclip_fight/val/No Fight/zMbmPG71_0.avi
#   inflating: ./xclip_fight/val/No Fight/zOqs7Oh9oDM_0.avi
#   inflating: ./xclip_fight/val/No Fight/zWevuNTR_0.avi
#   inflating: ./xclip_fight/val/No Fight/zsvJyWXp_0.avi
#    creating: ./xclip_fight/train/
#    creating: ./xclip_fight/train/No Fight/
#   inflating: ./xclip_fight/train/No Fight/9GFNxpur_0.avi
#   inflating: ./xclip_fight/train/No Fight/-1l5631l3fg_0.avi
#   inflating: ./xclip_fight/train/No Fight/-1l5631l3fg_1.avi
#   inflating: ./xclip_fight/train/No Fight/0AvTZRYx_0.avi
#   inflating: ./xclip_fight/train/No Fight/0GGPb4iO_0.avi
#   inflating: ./xclip_fight/train/No Fight/0H2s9UJcNJ0_0.avi
#   inflating: ./xclip_fight/train/No Fight/0H2s9UJcNJ0_1.avi
#   inflating: ./xclip_fight/train/No Fight/0H2s9UJcNJ0_2.avi
#   inflating: ./xclip_fight/train/No Fight/0NqPsSHdri8_0.avi
#   inflating: ./xclip_fight/train/No Fight/0QSeuqzpcOQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/0QSeuqzpcOQ_1.avi
#   inflating: ./xclip_fight/train/No Fight/0TFi8D8IBg4_0.avi
#   inflating: ./xclip_fight/train/No Fight/0TP13Nyn_0.avi
#   inflating: ./xclip_fight/train/No Fight/0YbzxGPE_0.avi
#   inflating: ./xclip_fight/train/No Fight/0_DzLlklZa0_0.avi
#   inflating: ./xclip_fight/train/No Fight/0_DzLlklZa0_1.avi
#   inflating: ./xclip_fight/train/No Fight/0_DzLlklZa0_2.avi
#   inflating: ./xclip_fight/train/No Fight/0_DzLlklZa0_3.avi
#   inflating: ./xclip_fight/train/No Fight/0vasozvJYvk_0.avi
#   inflating: ./xclip_fight/train/No Fight/0vasozvJYvk_1.avi
#   inflating: ./xclip_fight/train/No Fight/0vasozvJYvk_2.avi
#   inflating: ./xclip_fight/train/No Fight/0xoSMgad_0.avi
#   inflating: ./xclip_fight/train/No Fight/11vr9Jho_0.avi
#   inflating: ./xclip_fight/train/No Fight/14YZVngQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/16O0PIQP_0.avi
#   inflating: ./xclip_fight/train/No Fight/18xQQOv5_0.avi
#   inflating: ./xclip_fight/train/No Fight/1A3zEkCHBl8_0.avi
#   inflating: ./xclip_fight/train/No Fight/1A3zEkCHBl8_1.avi
#   inflating: ./xclip_fight/train/No Fight/1A3zEkCHBl8_2.avi
#   inflating: ./xclip_fight/train/No Fight/1O4KGHbRt3M_0.avi
#   inflating: ./xclip_fight/train/No Fight/1O4KGHbRt3M_1.avi
#   inflating: ./xclip_fight/train/No Fight/1OXrIaQK_0.avi
#   inflating: ./xclip_fight/train/No Fight/1QixA5m2_0.avi
#   inflating: ./xclip_fight/train/No Fight/1Ytq2moWGdw_0.avi
#   inflating: ./xclip_fight/train/No Fight/1ahhhDBQHxg_0.avi
#   inflating: ./xclip_fight/train/No Fight/1dsLuL5Lvbc_0.avi
#   inflating: ./xclip_fight/train/No Fight/1oEbrZhr_0.avi
#   inflating: ./xclip_fight/train/No Fight/1r91ACCe_0.avi
#   inflating: ./xclip_fight/train/No Fight/1tU4kxa51vw_0.avi
#   inflating: ./xclip_fight/train/No Fight/1tU4kxa51vw_1.avi
#   inflating: ./xclip_fight/train/No Fight/1tU4kxa51vw_2.avi
#   inflating: ./xclip_fight/train/No Fight/24E0xYYUz44_0.avi
#   inflating: ./xclip_fight/train/No Fight/24E0xYYUz44_1.avi
#   inflating: ./xclip_fight/train/No Fight/24E0xYYUz44_2.avi
#   inflating: ./xclip_fight/train/No Fight/2KMf6p5Q_0.avi
#   inflating: ./xclip_fight/train/No Fight/2KvkZ4yo_0.avi
#   inflating: ./xclip_fight/train/No Fight/2bBn7MLg_0.avi
#   inflating: ./xclip_fight/train/No Fight/2gkuUVq1_0.avi
#   inflating: ./xclip_fight/train/No Fight/310cmTrl_0.avi
#   inflating: ./xclip_fight/train/No Fight/36zWWHlldS8_0.avi
#   inflating: ./xclip_fight/train/No Fight/3CQi0ZCCHvc_0.avi
#   inflating: ./xclip_fight/train/No Fight/3CQi0ZCCHvc_1.avi
#   inflating: ./xclip_fight/train/No Fight/3CQi0ZCCHvc_2.avi
#   inflating: ./xclip_fight/train/No Fight/3Edebh8P_0.avi
#   inflating: ./xclip_fight/train/No Fight/3GUaHts0_0.avi
#   inflating: ./xclip_fight/train/No Fight/3HCpeji1_0.avi
#   inflating: ./xclip_fight/train/No Fight/3OKArbzg1uc_0.avi
#   inflating: ./xclip_fight/train/No Fight/3SS0E4SmTk8_0.avi
#   inflating: ./xclip_fight/train/No Fight/3SS0E4SmTk8_1.avi
#   inflating: ./xclip_fight/train/No Fight/3SS0E4SmTk8_2.avi
#   inflating: ./xclip_fight/train/No Fight/3TQqO4N8_0.avi
#   inflating: ./xclip_fight/train/No Fight/3Vw7MoNBgx4_0.avi
#   inflating: ./xclip_fight/train/No Fight/3Vw7MoNBgx4_1.avi
#   inflating: ./xclip_fight/train/No Fight/3ZY4hpms_0.avi
#   inflating: ./xclip_fight/train/No Fight/3djtKN3k_0.avi
#   inflating: ./xclip_fight/train/No Fight/3kpviz7lAMY_0.avi
#   inflating: ./xclip_fight/train/No Fight/3pRrZ9TS_0.avi
#   inflating: ./xclip_fight/train/No Fight/3qsou7p57Nk_0.avi
#   inflating: ./xclip_fight/train/No Fight/3qsou7p57Nk_1.avi
#   inflating: ./xclip_fight/train/No Fight/3z7ncTuu_0.avi
#   inflating: ./xclip_fight/train/No Fight/40l8LuP4_0.avi
#   inflating: ./xclip_fight/train/No Fight/4Fqxw7Nl_0.avi
#   inflating: ./xclip_fight/train/No Fight/4HH7yMU8y9A_0.avi
#   inflating: ./xclip_fight/train/No Fight/4HH7yMU8y9A_1.avi
#   inflating: ./xclip_fight/train/No Fight/4HH7yMU8y9A_2.avi
#   inflating: ./xclip_fight/train/No Fight/4HH7yMU8y9A_3.avi
#   inflating: ./xclip_fight/train/No Fight/4RgIlSIB_0.avi
#   inflating: ./xclip_fight/train/No Fight/4RqDG4I4iAk_0.avi
#   inflating: ./xclip_fight/train/No Fight/4RqDG4I4iAk_1.avi
#   inflating: ./xclip_fight/train/No Fight/4RqDG4I4iAk_2.avi
#   inflating: ./xclip_fight/train/No Fight/4fY0Iv4t_0.avi
#   inflating: ./xclip_fight/train/No Fight/4grE6XdY_0.avi
#   inflating: ./xclip_fight/train/No Fight/4jZvTj4j_0.avi
#   inflating: ./xclip_fight/train/No Fight/4x9VdiCc_0.avi
#   inflating: ./xclip_fight/train/No Fight/4yTlGiDoxBo_0.avi
#   inflating: ./xclip_fight/train/No Fight/4yTlGiDoxBo_1.avi
#   inflating: ./xclip_fight/train/No Fight/4yTlGiDoxBo_2.avi
#   inflating: ./xclip_fight/train/No Fight/551_wlV44GU_0.avi
#   inflating: ./xclip_fight/train/No Fight/551_wlV44GU_1.avi
#   inflating: ./xclip_fight/train/No Fight/5CwYc67y_0.avi
#   inflating: ./xclip_fight/train/No Fight/5RayT2Vy0EA_0.avi
#   inflating: ./xclip_fight/train/No Fight/5RayT2Vy0EA_1.avi
#   inflating: ./xclip_fight/train/No Fight/5RayT2Vy0EA_2.avi
#   inflating: ./xclip_fight/train/No Fight/5ieZt2nc_0.avi
#   inflating: ./xclip_fight/train/No Fight/5z1f5blMBdk_0.avi
#   inflating: ./xclip_fight/train/No Fight/5zVqOS0l_0.avi
#   inflating: ./xclip_fight/train/No Fight/6Dej3-k3MRE_0.avi
#   inflating: ./xclip_fight/train/No Fight/6Dej3-k3MRE_1.avi
#   inflating: ./xclip_fight/train/No Fight/6Dej3-k3MRE_2.avi
#   inflating: ./xclip_fight/train/No Fight/6JmCJbug_0.avi
#   inflating: ./xclip_fight/train/No Fight/6MSwCc0a_0.avi
#   inflating: ./xclip_fight/train/No Fight/6YmBBzyX_0.avi
#   inflating: ./xclip_fight/train/No Fight/6b254l7P_0.avi
#   inflating: ./xclip_fight/train/No Fight/6hots6jj_0.avi
#   inflating: ./xclip_fight/train/No Fight/6mrIIcAQ2fI_0.avi
#   inflating: ./xclip_fight/train/No Fight/6mrIIcAQ2fI_1.avi
#   inflating: ./xclip_fight/train/No Fight/6n48sGUq_0.avi
#   inflating: ./xclip_fight/train/No Fight/7-e3_UW7L7U_0.avi
#   inflating: ./xclip_fight/train/No Fight/7KXPekwe_0.avi
#   inflating: ./xclip_fight/train/No Fight/7QgVKRHB_0.avi
#   inflating: ./xclip_fight/train/No Fight/7R1m3V8C30g_0.avi
#   inflating: ./xclip_fight/train/No Fight/7R1m3V8C30g_1.avi
#   inflating: ./xclip_fight/train/No Fight/7icHwpC_d44_0.avi
#   inflating: ./xclip_fight/train/No Fight/7qtRgyFsk3s_0.avi
#   inflating: ./xclip_fight/train/No Fight/7qtRgyFsk3s_1.avi
#   inflating: ./xclip_fight/train/No Fight/80ySNph9_0.avi
#   inflating: ./xclip_fight/train/No Fight/85dkGMed_0.avi
#   inflating: ./xclip_fight/train/No Fight/86lUShJD_0.avi
#   inflating: ./xclip_fight/train/No Fight/88ndrvAZpE8_0.avi
#   inflating: ./xclip_fight/train/No Fight/88ndrvAZpE8_1.avi
#   inflating: ./xclip_fight/train/No Fight/8MuRpAyP_0.avi
#   inflating: ./xclip_fight/train/No Fight/8PuNOqvh_0.avi
#   inflating: ./xclip_fight/train/No Fight/8SWZq5we_fk_0.avi
#   inflating: ./xclip_fight/train/No Fight/8SWZq5we_fk_1.avi
#   inflating: ./xclip_fight/train/No Fight/8SWZq5we_fk_2.avi
#   inflating: ./xclip_fight/train/No Fight/8U6x0VMW_0.avi
#   inflating: ./xclip_fight/train/No Fight/8VqTmuq4HcI_0.avi
#   inflating: ./xclip_fight/train/No Fight/8VqTmuq4HcI_1.avi
#   inflating: ./xclip_fight/train/No Fight/8VqTmuq4HcI_2.avi
#   inflating: ./xclip_fight/train/No Fight/8pKKdS7rhXo_0.avi
#   inflating: ./xclip_fight/train/No Fight/9C_LQa7nnFg_0.avi
#   inflating: ./xclip_fight/train/No Fight/9C_LQa7nnFg_1.avi
#   inflating: ./xclip_fight/train/No Fight/9C_LQa7nnFg_2.avi
#   inflating: ./xclip_fight/train/No Fight/9CeKXVvD_0.avi
#   inflating: ./xclip_fight/train/No Fight/9F6pZn73_0.avi
#   inflating: ./xclip_fight/train/No Fight/9Jss3rP1_0.avi
#   inflating: ./xclip_fight/train/No Fight/9N4HikpX_0.avi
#   inflating: ./xclip_fight/train/No Fight/9U8J4abJGDg_0.avi
#   inflating: ./xclip_fight/train/No Fight/9haGKtHJ_0.avi
#   inflating: ./xclip_fight/train/No Fight/9nFtxkJ7ywg_0.avi
#   inflating: ./xclip_fight/train/No Fight/9qjOCoE7_0.avi
#   inflating: ./xclip_fight/train/No Fight/9uvZbSsy_0.avi
#   inflating: ./xclip_fight/train/No Fight/AEGjLggu_0.avi
#   inflating: ./xclip_fight/train/No Fight/AF4Rk1I2_0.avi
#   inflating: ./xclip_fight/train/No Fight/AG0ofjSP_0.avi
#   inflating: ./xclip_fight/train/No Fight/API3q8TBGu4_0.avi
#   inflating: ./xclip_fight/train/No Fight/API3q8TBGu4_1.avi
#   inflating: ./xclip_fight/train/No Fight/ATDMY6PzK9U_0.avi
#   inflating: ./xclip_fight/train/No Fight/AbD9xwut_0.avi
#   inflating: ./xclip_fight/train/No Fight/Ae3RYgGF_0.avi
#   inflating: ./xclip_fight/train/No Fight/Am9mUxPTvK4_0.avi
#   inflating: ./xclip_fight/train/No Fight/AsGAgf8U2rk_0.avi
#   inflating: ./xclip_fight/train/No Fight/Assault005_x264_0.avi
#   inflating: ./xclip_fight/train/No Fight/Assault005_x264_1.avi
#   inflating: ./xclip_fight/train/No Fight/Assault009_x264_0.avi
#   inflating: ./xclip_fight/train/No Fight/Assault009_x264_1.avi
#   inflating: ./xclip_fight/train/No Fight/Assault010_x264_0.avi
#   inflating: ./xclip_fight/train/No Fight/Assault010_x264_1.avi
#   inflating: ./xclip_fight/train/No Fight/Assault011_x264_0.avi
#   inflating: ./xclip_fight/train/No Fight/Assault011_x264_1.avi
#   inflating: ./xclip_fight/train/No Fight/AszvEN7z_0.avi
#   inflating: ./xclip_fight/train/No Fight/B3UdlWcs_0.avi
#   inflating: ./xclip_fight/train/No Fight/B6DO4tXb_0.avi
#   inflating: ./xclip_fight/train/No Fight/BEoVUtDm_0.avi
#   inflating: ./xclip_fight/train/No Fight/BKtajPcB_0.avi
#   inflating: ./xclip_fight/train/No Fight/BOLcNZ5O_0.avi
#   inflating: ./xclip_fight/train/No Fight/BOt8ZMpM_0.avi
#   inflating: ./xclip_fight/train/No Fight/BUjGBAPb_0.avi
#   inflating: ./xclip_fight/train/No Fight/BpargJW29Wo_0.avi
#   inflating: ./xclip_fight/train/No Fight/BpargJW29Wo_1.avi
#   inflating: ./xclip_fight/train/No Fight/C3cT1JGv_0.avi
#   inflating: ./xclip_fight/train/No Fight/C4SQF-UZzkA_0.avi
#   inflating: ./xclip_fight/train/No Fight/C4SQF-UZzkA_1.avi
#   inflating: ./xclip_fight/train/No Fight/C4SQF-UZzkA_2.avi
#   inflating: ./xclip_fight/train/No Fight/C76VU1PQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/C7Ty4ui5_0.avi
#   inflating: ./xclip_fight/train/No Fight/C7sNO3e2_0.avi
#   inflating: ./xclip_fight/train/No Fight/CKzrrb7E_0.avi
#   inflating: ./xclip_fight/train/No Fight/CPGf41PN_0.avi
#   inflating: ./xclip_fight/train/No Fight/CfPgoKqk_0.avi
#   inflating: ./xclip_fight/train/No Fight/CqJB8ZWLZ-o_0.avi
#   inflating: ./xclip_fight/train/No Fight/CqJB8ZWLZ-o_1.avi
#   inflating: ./xclip_fight/train/No Fight/CqJB8ZWLZ-o_2.avi
#   inflating: ./xclip_fight/train/No Fight/CqJB8ZWLZ-o_3.avi
#   inflating: ./xclip_fight/train/No Fight/D6cjNRiP_0.avi
#   inflating: ./xclip_fight/train/No Fight/DAMfrqpC_0.avi
#   inflating: ./xclip_fight/train/No Fight/DIsQwAdR8MI_0.avi
#   inflating: ./xclip_fight/train/No Fight/DL2gWMZA_0.avi
#   inflating: ./xclip_fight/train/No Fight/DRlOjUNi_0.avi
#   inflating: ./xclip_fight/train/No Fight/DThokDTW_0.avi
#   inflating: ./xclip_fight/train/No Fight/DTq6Gu30-uA_0.avi
#   inflating: ./xclip_fight/train/No Fight/DTq6Gu30-uA_1.avi
#   inflating: ./xclip_fight/train/No Fight/DTq6Gu30-uA_2.avi
#   inflating: ./xclip_fight/train/No Fight/DWEBHWM9_0.avi
#   inflating: ./xclip_fight/train/No Fight/DX5wwFlF_0.avi
#   inflating: ./xclip_fight/train/No Fight/DZdLP0rd_0.avi
#   inflating: ./xclip_fight/train/No Fight/DjLWv5mr_0.avi
#   inflating: ./xclip_fight/train/No Fight/DrKgJwIv_0.avi
#   inflating: ./xclip_fight/train/No Fight/E0Huf4Qi0JE_0.avi
#   inflating: ./xclip_fight/train/No Fight/E0rUpvbX_0.avi
#   inflating: ./xclip_fight/train/No Fight/E2gqgFNyPL8_0.avi
#   inflating: ./xclip_fight/train/No Fight/E2gqgFNyPL8_1.avi
#   inflating: ./xclip_fight/train/No Fight/E2gqgFNyPL8_2.avi
#   inflating: ./xclip_fight/train/No Fight/EBwt3Thb_0.avi
#   inflating: ./xclip_fight/train/No Fight/EDaOod1H_0.avi
#   inflating: ./xclip_fight/train/No Fight/EGhykgb4_0.avi
#   inflating: ./xclip_fight/train/No Fight/ELL0jBUP_0.avi
#   inflating: ./xclip_fight/train/No Fight/EUgjFWbm_0.avi
#   inflating: ./xclip_fight/train/No Fight/EckGCByW_0.avi
#   inflating: ./xclip_fight/train/No Fight/EizIwdII_0.avi
#   inflating: ./xclip_fight/train/No Fight/F7W6PQ3V3y8_0.avi
#   inflating: ./xclip_fight/train/No Fight/F7W6PQ3V3y8_1.avi
#   inflating: ./xclip_fight/train/No Fight/F7W6PQ3V3y8_2.avi
#   inflating: ./xclip_fight/train/No Fight/F7W6PQ3V3y8_3.avi
#   inflating: ./xclip_fight/train/No Fight/FB3eqRE8_0.avi
#   inflating: ./xclip_fight/train/No Fight/FKl98mfo_0.avi
#   inflating: ./xclip_fight/train/No Fight/FPU7QpO4_0.avi
#   inflating: ./xclip_fight/train/No Fight/FSaZ8wiFw8Q_0.avi
#   inflating: ./xclip_fight/train/No Fight/FWsNU4WI_0.avi
#   inflating: ./xclip_fight/train/No Fight/FZDDNtcaBcw_0.avi
#   inflating: ./xclip_fight/train/No Fight/Fighting014_x264_0.avi
#   inflating: ./xclip_fight/train/No Fight/Fighting014_x264_1.avi
#   inflating: ./xclip_fight/train/No Fight/Fk3lg4wG_0.avi
#   inflating: ./xclip_fight/train/No Fight/Fn4sSVbO_0.avi
#   inflating: ./xclip_fight/train/No Fight/FrwBev61_0.avi
#   inflating: ./xclip_fight/train/No Fight/G0rgy9Ts_0.avi
#   inflating: ./xclip_fight/train/No Fight/G9uNZGcK_0.avi
#   inflating: ./xclip_fight/train/No Fight/GL9jSSxg_0.avi
#   inflating: ./xclip_fight/train/No Fight/GVdnjHyU_0.avi
#   inflating: ./xclip_fight/train/No Fight/GZWxDB1c_0.avi
#   inflating: ./xclip_fight/train/No Fight/GgT095uX_0.avi
#   inflating: ./xclip_fight/train/No Fight/GhZRf4GIw0w_0.avi
#   inflating: ./xclip_fight/train/No Fight/GodUly2k_0.avi
#   inflating: ./xclip_fight/train/No Fight/GqDA8E4j_0.avi
#   inflating: ./xclip_fight/train/No Fight/Gr3ikl6A2bE_0.avi
#   inflating: ./xclip_fight/train/No Fight/GzPhV725_0.avi
#   inflating: ./xclip_fight/train/No Fight/H1AzC-GyKto_0.avi
#   inflating: ./xclip_fight/train/No Fight/H1AzC-GyKto_1.avi
#   inflating: ./xclip_fight/train/No Fight/H1AzC-GyKto_2.avi
#   inflating: ./xclip_fight/train/No Fight/H1AzC-GyKto_3.avi
#   inflating: ./xclip_fight/train/No Fight/H68yvSdp_0.avi
#   inflating: ./xclip_fight/train/No Fight/HAh9eqtO_0.avi
#   inflating: ./xclip_fight/train/No Fight/HAoCHqFV_0.avi
#   inflating: ./xclip_fight/train/No Fight/HG8xQFSd_0.avi
#   inflating: ./xclip_fight/train/No Fight/HUuRelBW_0.avi
#   inflating: ./xclip_fight/train/No Fight/HVRUChVh_0.avi
#   inflating: ./xclip_fight/train/No Fight/HVSv9sgz2ZI_0.avi
#   inflating: ./xclip_fight/train/No Fight/HVSv9sgz2ZI_1.avi
#   inflating: ./xclip_fight/train/No Fight/HVSv9sgz2ZI_2.avi
#   inflating: ./xclip_fight/train/No Fight/HVSv9sgz2ZI_3.avi
#   inflating: ./xclip_fight/train/No Fight/HW48LUZKOL4_0.avi
#   inflating: ./xclip_fight/train/No Fight/HW48LUZKOL4_1.avi
#   inflating: ./xclip_fight/train/No Fight/HW48LUZKOL4_2.avi
#   inflating: ./xclip_fight/train/No Fight/HW48LUZKOL4_3.avi
#   inflating: ./xclip_fight/train/No Fight/HYkbCvPj_0.avi
#   inflating: ./xclip_fight/train/No Fight/H_VQJU0Bqpc_0.avi
#   inflating: ./xclip_fight/train/No Fight/H_VQJU0Bqpc_1.avi
#   inflating: ./xclip_fight/train/No Fight/H_VQJU0Bqpc_2.avi
#   inflating: ./xclip_fight/train/No Fight/H_VQJU0Bqpc_3.avi
#   inflating: ./xclip_fight/train/No Fight/HbfZYAXw_0.avi
#   inflating: ./xclip_fight/train/No Fight/HodGUj8s_0.avi
#   inflating: ./xclip_fight/train/No Fight/Hsvzcq2l_0.avi
#   inflating: ./xclip_fight/train/No Fight/HvfhYJ8b_0.avi
#   inflating: ./xclip_fight/train/No Fight/I-x0G5pAan0_0.avi
#   inflating: ./xclip_fight/train/No Fight/I-x0G5pAan0_1.avi
#   inflating: ./xclip_fight/train/No Fight/I7u5I8Oa_0.avi
#   inflating: ./xclip_fight/train/No Fight/IGCZWiP8_0.avi
#   inflating: ./xclip_fight/train/No Fight/Isob76kh_0.avi
#   inflating: ./xclip_fight/train/No Fight/IynvwHe9W3U_0.avi
#   inflating: ./xclip_fight/train/No Fight/IynvwHe9W3U_1.avi
#   inflating: ./xclip_fight/train/No Fight/IynvwHe9W3U_2.avi
#   inflating: ./xclip_fight/train/No Fight/IynvwHe9W3U_3.avi
#   inflating: ./xclip_fight/train/No Fight/J2Am3J0z_0.avi
#   inflating: ./xclip_fight/train/No Fight/J2rsCgMC_0.avi
#   inflating: ./xclip_fight/train/No Fight/JBRqNBaP_0.avi
#   inflating: ./xclip_fight/train/No Fight/JD9JJbiJ_0.avi
#   inflating: ./xclip_fight/train/No Fight/JPIeYvRgo6I_0.avi
#   inflating: ./xclip_fight/train/No Fight/JPIeYvRgo6I_1.avi
#   inflating: ./xclip_fight/train/No Fight/JPIeYvRgo6I_2.avi
#   inflating: ./xclip_fight/train/No Fight/JPMLt2ZH_0.avi
#   inflating: ./xclip_fight/train/No Fight/JWFfsHEG_0.avi
#   inflating: ./xclip_fight/train/No Fight/JgXAUoyJ_0.avi
#   inflating: ./xclip_fight/train/No Fight/JsjF2OSJ_0.avi
#   inflating: ./xclip_fight/train/No Fight/JwTPruSFTjk_0.avi
#   inflating: ./xclip_fight/train/No Fight/JwTPruSFTjk_1.avi
#   inflating: ./xclip_fight/train/No Fight/JwfajujK_0.avi
#   inflating: ./xclip_fight/train/No Fight/JxpNuQop_0.avi
#   inflating: ./xclip_fight/train/No Fight/K4700BuM_0.avi
#   inflating: ./xclip_fight/train/No Fight/KDOVTf7T_0.avi
#   inflating: ./xclip_fight/train/No Fight/KLEwMKTN_0.avi
#   inflating: ./xclip_fight/train/No Fight/KOaUqaC8_0.avi
#   inflating: ./xclip_fight/train/No Fight/KQTiHlA11fM_0.avi
#   inflating: ./xclip_fight/train/No Fight/KQTiHlA11fM_1.avi
#   inflating: ./xclip_fight/train/No Fight/KQTiHlA11fM_2.avi
#   inflating: ./xclip_fight/train/No Fight/KQTiHlA11fM_3.avi
#   inflating: ./xclip_fight/train/No Fight/K_7hT4N2QCE_0.avi
#   inflating: ./xclip_fight/train/No Fight/KklEipxk_0.avi
#   inflating: ./xclip_fight/train/No Fight/Km94kW0O_0.avi
#   inflating: ./xclip_fight/train/No Fight/KxOHVkVQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/L9tYVvJY_0.avi
#   inflating: ./xclip_fight/train/No Fight/LLo_TXIz5-g_0.avi
#   inflating: ./xclip_fight/train/No Fight/LLo_TXIz5-g_1.avi
#   inflating: ./xclip_fight/train/No Fight/LMNJJere_0.avi
#   inflating: ./xclip_fight/train/No Fight/LSJPhJTB_0.avi
#   inflating: ./xclip_fight/train/No Fight/La60qonu_0.avi
#   inflating: ./xclip_fight/train/No Fight/La9lzohO_0.avi
#   inflating: ./xclip_fight/train/No Fight/LbYQs9oA_0.avi
#   inflating: ./xclip_fight/train/No Fight/LiCakkNH_0.avi
#   inflating: ./xclip_fight/train/No Fight/LqW9A21g_0.avi
#   inflating: ./xclip_fight/train/No Fight/Lui5zaon_0.avi
#   inflating: ./xclip_fight/train/No Fight/M4syignQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/MBxCX6pw_0.avi
#   inflating: ./xclip_fight/train/No Fight/MOST Shocking CCTV footage (_TwPzPRK7dc)_0.avi
#   inflating: ./xclip_fight/train/No Fight/MOST Shocking CCTV footage (_TwPzPRK7dc)_1.avi
#   inflating: ./xclip_fight/train/No Fight/MX77f2TD_0.avi
#   inflating: ./xclip_fight/train/No Fight/Ma1iva6R_0.avi
#   inflating: ./xclip_fight/train/No Fight/McDxnU7x_0.avi
#   inflating: ./xclip_fight/train/No Fight/MhVfgPWz_0.avi
#   inflating: ./xclip_fight/train/No Fight/MhiGg6f7_0.avi
#   inflating: ./xclip_fight/train/No Fight/MmUtpm6Z_0.avi
#   inflating: ./xclip_fight/train/No Fight/Mv3d3zJy_0.avi
#   inflating: ./xclip_fight/train/No Fight/MvYkXHIi_0.avi
#   inflating: ./xclip_fight/train/No Fight/MwZvUQRO_0.avi
#   inflating: ./xclip_fight/train/No Fight/N1Q9v-saJ_g_0.avi
#   inflating: ./xclip_fight/train/No Fight/NEUya2Rr_0.avi
#   inflating: ./xclip_fight/train/No Fight/NPeKBgURcxI_0.avi
#   inflating: ./xclip_fight/train/No Fight/NPeKBgURcxI_1.avi
#   inflating: ./xclip_fight/train/No Fight/NPeKBgURcxI_2.avi
#   inflating: ./xclip_fight/train/No Fight/NSdXEN1l_0.avi
#   inflating: ./xclip_fight/train/No Fight/NmNKzttk_0.avi
#   inflating: ./xclip_fight/train/No Fight/NvYo6CS_i_A_0.avi
#   inflating: ./xclip_fight/train/No Fight/NvYo6CS_i_A_1.avi
#   inflating: ./xclip_fight/train/No Fight/NxtwlqSnLbY_0.avi
#   inflating: ./xclip_fight/train/No Fight/NxtwlqSnLbY_1.avi
#   inflating: ./xclip_fight/train/No Fight/OAFsSiyX_0.avi
#   inflating: ./xclip_fight/train/No Fight/OAfV0xPIhZw_0.avi
#   inflating: ./xclip_fight/train/No Fight/OAfV0xPIhZw_1.avi
#   inflating: ./xclip_fight/train/No Fight/OCseFRss_0.avi
#   inflating: ./xclip_fight/train/No Fight/OFwYyouR_0.avi
#   inflating: ./xclip_fight/train/No Fight/OTVE3eLAuUM_0.avi
#   inflating: ./xclip_fight/train/No Fight/OTVE3eLAuUM_1.avi
#   inflating: ./xclip_fight/train/No Fight/OTVE3eLAuUM_2.avi
#   inflating: ./xclip_fight/train/No Fight/OU7AM5fv_0.avi
#   inflating: ./xclip_fight/train/No Fight/OakN3f1N_0.avi
#   inflating: ./xclip_fight/train/No Fight/OdxnpEnn_0.avi
#   inflating: ./xclip_fight/train/No Fight/OznqyUJq_0.avi
#   inflating: ./xclip_fight/train/No Fight/P8jyDT3M_0.avi
#   inflating: ./xclip_fight/train/No Fight/PFw7SeFOD04_0.avi
#   inflating: ./xclip_fight/train/No Fight/PFw7SeFOD04_1.avi
#   inflating: ./xclip_fight/train/No Fight/PJDdPv2b9-s_0.avi
#   inflating: ./xclip_fight/train/No Fight/PJDdPv2b9-s_1.avi
#   inflating: ./xclip_fight/train/No Fight/PNoO9WGJ_0.avi
#   inflating: ./xclip_fight/train/No Fight/PTy2vx8Ejas_0.avi
#   inflating: ./xclip_fight/train/No Fight/Pe1uIhp4dAQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/Pe1uIhp4dAQ_1.avi
#   inflating: ./xclip_fight/train/No Fight/PqB7UvdW_0.avi
#   inflating: ./xclip_fight/train/No Fight/PxhG17WC_0.avi
#   inflating: ./xclip_fight/train/No Fight/Q876qiBJYfA_0.avi
#   inflating: ./xclip_fight/train/No Fight/Q876qiBJYfA_1.avi
#   inflating: ./xclip_fight/train/No Fight/Q876qiBJYfA_2.avi
#   inflating: ./xclip_fight/train/No Fight/QCgEbCBH_0.avi
#   inflating: ./xclip_fight/train/No Fight/QUGT4a6qcJs_0.avi
#   inflating: ./xclip_fight/train/No Fight/Qqfn1urQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/QzNWGaQi_0.avi
#   inflating: ./xclip_fight/train/No Fight/R1A_AxUKosk_0.avi
#   inflating: ./xclip_fight/train/No Fight/R1A_AxUKosk_1.avi
#   inflating: ./xclip_fight/train/No Fight/R2x2rOWh_0.avi
#   inflating: ./xclip_fight/train/No Fight/RFAA8QO7_0.avi
#   inflating: ./xclip_fight/train/No Fight/RFUr2krY_0.avi
#   inflating: ./xclip_fight/train/No Fight/RGIpCpdlzI8_0.avi
#   inflating: ./xclip_fight/train/No Fight/RGIpCpdlzI8_1.avi
#   inflating: ./xclip_fight/train/No Fight/RNOSWjgC_0.avi
#   inflating: ./xclip_fight/train/No Fight/RPESrVE2_0.avi
#   inflating: ./xclip_fight/train/No Fight/RQbYptdw_0.avi
#   inflating: ./xclip_fight/train/No Fight/RR23nrP0_0.avi
#   inflating: ./xclip_fight/train/No Fight/RUwo8c4s_0.avi
#   inflating: ./xclip_fight/train/No Fight/RVV3lolZ_0.avi
#   inflating: ./xclip_fight/train/No Fight/RbpXgk5M1S0_0.avi
#   inflating: ./xclip_fight/train/No Fight/RbpXgk5M1S0_1.avi
#   inflating: ./xclip_fight/train/No Fight/RbpXgk5M1S0_2.avi
#   inflating: ./xclip_fight/train/No Fight/RfFGwwhG_0.avi
#   inflating: ./xclip_fight/train/No Fight/RfqBhe5z_0.avi
#   inflating: ./xclip_fight/train/No Fight/Ri_poPbOu-k_0.avi
#   inflating: ./xclip_fight/train/No Fight/Ri_poPbOu-k_1.avi
#   inflating: ./xclip_fight/train/No Fight/Ri_poPbOu-k_2.avi
#   inflating: ./xclip_fight/train/No Fight/S5dmvVF4_0.avi
#   inflating: ./xclip_fight/train/No Fight/SCnBiAteLVI_0.avi
#   inflating: ./xclip_fight/train/No Fight/SCnBiAteLVI_1.avi
#   inflating: ./xclip_fight/train/No Fight/SCnBiAteLVI_2.avi
#   inflating: ./xclip_fight/train/No Fight/SJ9WphBI_0.avi
#   inflating: ./xclip_fight/train/No Fight/SVdz24hD_0.avi
#   inflating: ./xclip_fight/train/No Fight/SaIUKN4N_0.avi
#   inflating: ./xclip_fight/train/No Fight/Suv_mMs8J9g_0.avi
#   inflating: ./xclip_fight/train/No Fight/Swr7caI0_0.avi
#   inflating: ./xclip_fight/train/No Fight/THqDidIr4Xs_0.avi
#   inflating: ./xclip_fight/train/No Fight/THqDidIr4Xs_1.avi
#   inflating: ./xclip_fight/train/No Fight/TJfoIe801t8_0.avi
#   inflating: ./xclip_fight/train/No Fight/TSHiCcMS_0.avi
#   inflating: ./xclip_fight/train/No Fight/TX2ePcRo_0.avi
#   inflating: ./xclip_fight/train/No Fight/TYX5vuHO_0.avi
#   inflating: ./xclip_fight/train/No Fight/TYsebroPeGY_0.avi
#   inflating: ./xclip_fight/train/No Fight/TYsebroPeGY_1.avi
#   inflating: ./xclip_fight/train/No Fight/TfDHgxDm_0.avi
#   inflating: ./xclip_fight/train/No Fight/TuWan04E3gQ_0.avi
#   inflating: ./xclip_fight/train/No Fight/TuWan04E3gQ_1.avi
# ...
#   inflating: ./xclip_fight/train/Fight/vBwKQfJYG1Q_3.avi
#   inflating: ./xclip_fight/train/Fight/vBwKQfJYG1Q_4.avi
#   inflating: ./xclip_fight/train/Fight/vBwKQfJYG1Q_5.avi
#   inflating: ./xclip_fight/train/Fight/vBwKQfJYG1Q_6.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_0.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_1.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_2.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_3.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_4.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_5.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_6.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_7.avi
#   inflating: ./xclip_fight/train/Fight/vQKHxtrdEHM_9.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback (1)_54.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback (1)_55.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback (2)_66.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback (2)_74.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback_92.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback_93.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback_94.avi
#   inflating: ./xclip_fight/train/Fight/videoplayback_95.avi
#   inflating: ./xclip_fight/train/Fight/w1T3NmEAt00_0.avi
#   inflating: ./xclip_fight/train/Fight/wetrew_1195.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1204.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1205.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1206.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1207.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1208.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1223.avi
#   inflating: ./xclip_fight/train/Fight/wetyh_1224.avi
#   inflating: ./xclip_fight/train/Fight/wxdRVAZk_0.avi
#   inflating: ./xclip_fight/train/Fight/wxdRVAZk_1.avi
#   inflating: ./xclip_fight/train/Fight/xKq3hlefCUI_0.avi
#   inflating: ./xclip_fight/train/Fight/xKq3hlefCUI_1.avi
#   inflating: ./xclip_fight/train/Fight/xrlCdUaagHY_0.avi
#   inflating: ./xclip_fight/train/Fight/z19nkHMw_0.avi
#   inflating: ./xclip_fight/train/Fight/z19nkHMw_1.avi
#   inflating: ./xclip_fight/train/Fight/z1WyVUv8_0.avi
#   inflating: ./xclip_fight/train/Fight/z1WyVUv8_1.avi
#   inflating: ./xclip_fight/train/Fight/z1WyVUv8_2.avi
#   inflating: ./xclip_fight/train/Fight/z7dOEJwUpVk_0.avi
#   inflating: ./xclip_fight/train/Fight/zuCTuKvj_0.avi
#   inflating: ./xclip_fight/train/Fight/zuCTuKvj_1.avi
#   inflating: ./xclip_fight/train/Fight/zuCTuKvj_2.avi
#   inflating: ./xclip_fight/train/Fight/zuCTuKvj_3.avi
#   inflating: ./xclip_fight/train/Fight/zuCTuKvj_5.avi
# error:  cannot create ./xclip_fight/train/Fight/#U0444#U2555#U0434#U0445#U0435#U2502#U0445#U043d#U0420#U0445#U2551#U0427#U0449#U0417#U041c#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0445#U041d#U2524#U0445#U255d#U0425#U0445#U041f#U0421#U0446#U0425#U2591#U0445#U0420#U041d#U0447#U0424#U2556#U0445#U043d#U0420#U0445#U0417#U2551#U0446#U0419#U041b#U044f#U255d#U041c#U0446#U0428#U043f#U0444#U2557#U0410#U0444#U2563#U0418#U0445#U041e#U042f#U0445#U042b#U0430#U044f#U255d#U042f#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_220.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0444#U2555#U0434#U0445#U0435#U2502#U0445#U043d#U0420#U0445#U2551#U0427#U0449#U0417#U041c#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0445#U041d#U2524#U0445#U255d#U0425#U0445#U041f#U0421#U0446#U0425#U2591#U0445#U0420#U041d#U0447#U0424#U2556#U0445#U043d#U0420#U0445#U0417#U2551#U0446#U0419#U041b#U044f#U255d#U041c#U0446#U0428#U043f#U0444#U2557#U0410#U0444#U2563#U0418#U0445#U041e#U042f#U0445#U042b#U0430#U044f#U255d#U042f#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_221.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041c#U0448#U0431#U041c#U0448#U0410#U0411#U0446#U042d#U2510#U0445#U041f#U043b#U0446#U042d#U0435#U0445#U2555#U043e#U0446#U2524#U255b#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0444#U2555#U0410#U0447#U0437#U0422#U0446#U042c#U0419#U0444#U2551#U2551#U0448#U0437#U0411#U0446#U043d#U2557#U0447#U0435#U042e#U0444#U2551#U0416#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0446#U0413#U0438#U0447#U0413#U0418#U0447#U0424#U2557#U0449#U042d#U0432#U044f#U255d#U0411_urlgot_222.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041c#U0448#U0431#U041c#U0448#U0410#U0411#U0446#U042d#U2510#U0445#U041f#U043b#U0446#U042d#U0435#U0445#U2555#U043e#U0446#U2524#U255b#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0444#U2555#U0410#U0447#U0437#U0422#U0446#U042c#U0419#U0444#U2551#U2551#U0448#U0437#U0411#U0446#U043d#U2557#U0447#U0435#U042e#U0444#U2551#U0416#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0446#U0413#U0438#U0447#U0413#U0418#U0447#U0424#U2557#U0449#U042d#U0432#U044f#U255d#U0411_urlgot_223.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041c#U0448#U0431#U041c#U0448#U0410#U0411#U0446#U042d#U2510#U0445#U041f#U043b#U0446#U042d#U0435#U0445#U2555#U043e#U0446#U2524#U255b#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0444#U2555#U0410#U0447#U0437#U0422#U0446#U042c#U0419#U0444#U2551#U2551#U0448#U0437#U0411#U0446#U043d#U2557#U0447#U0435#U042e#U0444#U2551#U0416#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0446#U0413#U0438#U0447#U0413#U0418#U0447#U0424#U2557#U0449#U042d#U0432#U044f#U255d#U0411_urlgot_224.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041e#U0445#U041e#U0438#U0449#U0417#U041c#U0449#U042d#U0432#U0444#U2555#U0410#U0448#U0438#U0410#U0444#U2555#U041d#U0445#U0420#U0418#U0445#U2591#U2592#U0445#U255d#U0410#U0446#U0419#U0423#U044f#U255d#U041c#U0446#U041b#U0419#U0446#U042e#U2562#U0445#U041f#U0428#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U041e#U2591#U0445#U042c#U2551#U0444#U2555#U0410#U0447#U0419#U0417#U0446#U2556#U2556#U0444#U2563#U2592#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_233.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041e#U0445#U041e#U0438#U0449#U0417#U041c#U0449#U042d#U0432#U0444#U2555#U0410#U0448#U0438#U0410#U0444#U2555#U041d#U0445#U0420#U0418#U0445#U2591#U2592#U0445#U255d#U0410#U0446#U0419#U0423#U044f#U255d#U041c#U0446#U041b#U0419#U0446#U042e#U2562#U0445#U041f#U0428#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U041e#U2591#U0445#U042c#U2551#U0444#U2555#U0410#U0447#U0419#U0417#U0446#U2556#U2556#U0444#U2563#U2592#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_235.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041e#U0445#U041e#U0438#U0449#U0417#U041c#U0449#U042d#U0432#U0444#U2555#U0410#U0448#U0438#U0410#U0444#U2555#U041d#U0445#U0420#U0418#U0445#U2591#U2592#U0445#U255d#U0410#U0446#U0419#U0423#U044f#U255d#U041c#U0446#U041b#U0419#U0446#U042e#U2562#U0445#U041f#U0428#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U041e#U2591#U0445#U042c#U2551#U0444#U2555#U0410#U0447#U0419#U0417#U0446#U2556#U2556#U0444#U2563#U2592#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_236.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041e#U0445#U041e#U0438#U0449#U0417#U041c#U0449#U042d#U0432#U0444#U2555#U0410#U0448#U0438#U0410#U0444#U2555#U041d#U0445#U0420#U0418#U0445#U2591#U2592#U0445#U255d#U0410#U0446#U0419#U0423#U044f#U255d#U041c#U0446#U041b#U0419#U0446#U042e#U2562#U0445#U041f#U0428#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U041e#U2591#U0445#U042c#U2551#U0444#U2555#U0410#U0447#U0419#U0417#U0446#U2556#U2556#U0444#U2563#U2592#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_237.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041e#U0445#U041e#U0438#U0449#U0417#U041c#U0449#U042d#U0432#U0444#U2555#U0410#U0448#U0438#U0410#U0444#U2555#U041d#U0445#U0420#U0418#U0445#U2591#U2592#U0445#U255d#U0410#U0446#U0419#U0423#U044f#U255d#U041c#U0446#U041b#U0419#U0446#U042e#U2562#U0445#U041f#U0428#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U041e#U2591#U0445#U042c#U2551#U0444#U2555#U0410#U0447#U0419#U0417#U0446#U2556#U2556#U0444#U2563#U2592#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_238.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0420#U041e#U0445#U041e#U0438#U0449#U0417#U041c#U0449#U042d#U0432#U0444#U2555#U0410#U0448#U0438#U0410#U0444#U2555#U041d#U0445#U0420#U0418#U0445#U2591#U2592#U0445#U255d#U0410#U0446#U0419#U0423#U044f#U255d#U041c#U0446#U041b#U0419#U0446#U042e#U2562#U0445#U041f#U0428#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U041e#U2591#U0445#U042c#U2551#U0444#U2555#U0410#U0447#U0419#U0417#U0446#U2556#U2556#U0444#U2563#U2592#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0445#U0415#U0438#U0447#U0438#U041b_urlgot_242.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0434#U0437#U0449#U0429#U0416#U0447#U0420#U0416#U0445#U041f#U0421#U0445#U2551#U0427#U0445#U041f#U0421#U0447#U0424#U042f#U0447#U0430#U041d#U0444#U2551#U2551#U0444#U2551#U041b#U0444#U2557#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0446#U0419#U041b#U0447#U042c#U042f#U0447#U041b#U0430#U044f#U255d#U0411_urlgot_121.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0434#U0437#U0449#U0429#U0416#U0447#U0420#U0416#U0445#U041f#U0421#U0445#U2551#U0427#U0445#U041f#U0421#U0447#U0424#U042f#U0447#U0430#U041d#U0444#U2551#U2551#U0444#U2551#U041b#U0444#U2557#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0446#U0419#U041b#U0447#U042c#U042f#U0447#U041b#U0430#U044f#U255d#U0411_urlgot_122.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0434#U0437#U0449#U0429#U0416#U0447#U0420#U0416#U0445#U041f#U0421#U0445#U2551#U0427#U0445#U041f#U0421#U0447#U0424#U042f#U0447#U0430#U041d#U0444#U2551#U2551#U0444#U2551#U041b#U0444#U2557#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0446#U0419#U041b#U0447#U042c#U042f#U0447#U041b#U0430#U044f#U255d#U0411_urlgot_123.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0434#U0437#U0449#U0429#U0416#U0447#U0420#U0416#U0445#U041f#U0421#U0445#U2551#U0427#U0445#U041f#U0421#U0447#U0424#U042f#U0447#U0430#U041d#U0444#U2551#U2551#U0444#U2551#U041b#U0444#U2557#U2562#U044f#U255d#U041c#U0444#U2555#U041b#U0446#U0419#U041b#U0447#U042c#U042f#U0447#U041b#U0430#U044f#U255d#U0411_urlgot_127.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U0436#U0412#U0446#U042e#U042c#U0444#U2555#U041d#U0446#U0428#U043f#U0447#U042b#U0421#U0446#U041e#U0437,#U0448#U2591#U0411#U0444#U255d#U042a#U0447#U042b#U2555#U0444#U2510#U0431#U0445#U2591#U041f#U0444#U255d#U0429#U0444#U2555#U2551#U0444#U2551#U0416#U0446#U0419#U0423#U0446#U042e#U2562#U0447#U042b#U2524#U0446#U041e#U0435#U0444#U2557#U041e#U0444#U2551#U041c#U0446#U0435#U255d#U0448#U2556#U2502#U0444#U2555#U041b#U0445#U041e#U2557_urlgot_254.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U2563#U2510#U0444#U2555#U042c#U0447#U042c#U0411#U0446#U2592#U0425#U0445#U0434#U2524#U0445#U2555#U0412#U0446#U255c#U043e#U0449#U0428#U2502#U0445#U041c#U2551#U0449#U0423#U042c#U0447#U042b#U0412#U0449#U0425#U0417#U0446#U2593#U2502#U0449#U0429#U0417#U0446#U042d#U0421#U0446#U042a#U2524#U0445#U041a#U042b#U0444#U2551#U041b#U0444#U2557#U2562#U0447#U042b#U0421#U0446#U041e#U0437#U0448#U0437#U0416#U0449#U0432#U04212_urlgot_138.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U2563#U2510#U0444#U2555#U042c#U0447#U042c#U0411#U0446#U2592#U0425#U0445#U0434#U2524#U0445#U2555#U0412#U0446#U255c#U043e#U0449#U0428#U2502#U0445#U041c#U2551#U0449#U0423#U042c#U0447#U042b#U0412#U0449#U0425#U0417#U0446#U2593#U2502#U0449#U0429#U0417#U0446#U042d#U0421#U0446#U042a#U2524#U0445#U041a#U042b#U0444#U2551#U041b#U0444#U2557#U2562#U0447#U042b#U0421#U0446#U041e#U0437#U0448#U0437#U0416#U0449#U0432#U04212_urlgot_139.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U2563#U2510#U0444#U2555#U042c#U0447#U042c#U0411#U0446#U2592#U0425#U0445#U0434#U2524#U0445#U2555#U0412#U0446#U255c#U043e#U0449#U0428#U2502#U0445#U041c#U2551#U0449#U0423#U042c#U0447#U042b#U0412#U0449#U0425#U0417#U0446#U2593#U2502#U0449#U0429#U0417#U0446#U042d#U0421#U0446#U042a#U2524#U0445#U041a#U042b#U0444#U2551#U041b#U0444#U2557#U2562#U0447#U042b#U0421#U0446#U041e#U0437#U0448#U0437#U0416#U0449#U0432#U04212_urlgot_140.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0445#U2563#U2510#U0444#U2555#U042c#U0447#U042c#U0411#U0446#U2592#U0425#U0445#U0434#U2524#U0445#U2555#U0412#U0446#U255c#U043e#U0449#U0428#U2502#U0445#U041c#U2551#U0449#U0423#U042c#U0447#U042b#U0412#U0449#U0425#U0417#U0446#U2593#U2502#U0449#U0429#U0417#U0446#U042d#U0421#U0446#U042a#U2524#U0445#U041a#U042b#U0444#U2551#U041b#U0444#U2557#U2562#U0447#U042b#U0421#U0446#U041e#U0437#U0448#U0437#U0416#U0449#U0432#U04212_urlgot_141.avi
#         File name too long
#   inflating: ./xclip_fight/train/Fight/#U0447#U042b#U0421#U0446#U041e#U0437-#U0448#U041b#U2592#U0445#U042b#U255c#U0448#U043d#U0436#U0445#U043f#U042f#U0446#U042a#U2524#U0445#U041a#U042b#U0446#U043e#U2524#U0446#U0419#U0423#U0445#U0435#U2502#U0445#U043b#U041c#U0447#U041a#U043f_urlgot_210.avi
# error:  cannot create ./xclip_fight/train/Fight/#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0449#U0434#U0420#U0445#U041e#U0415#U0444#U2555#U0410#U0447#U255b#U0434#U0445#U2591#U041f#U0444#U255d#U0429#U0446#U0419#U0423#U0446#U042e#U2562#U0446#U0426#U0427#U0446#U043e#U2524 #U0448#U0410#U0411#U0446#U042d#U2510#U0447#U042e#U043c#U0449#U0427#U2524#U0445#U041f#U0421#U0449#U0433#U0429#U0444#U2551#U0416_urlgot_267.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0449#U0434#U0420#U0445#U041e#U0415#U0444#U2555#U0410#U0447#U255b#U0434#U0445#U2591#U041f#U0444#U255d#U0429#U0446#U0419#U0423#U0446#U042e#U2562#U0446#U0426#U0427#U0446#U043e#U2524 #U0448#U0410#U0411#U0446#U042d#U2510#U0447#U042e#U043c#U0449#U0427#U2524#U0445#U041f#U0421#U0449#U0433#U0429#U0444#U2551#U0416_urlgot_268.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0447#U042b#U0421#U0446#U041e#U0437#U0446#U041b#U041d#U0444#U2555#U041b#U0449#U0434#U0420#U0445#U041e#U0415#U0444#U2555#U0410#U0447#U255b#U0434#U0445#U2591#U041f#U0444#U255d#U0429#U0446#U0419#U0423#U0446#U042e#U2562#U0446#U0426#U0427#U0446#U043e#U2524 #U0448#U0410#U0411#U0446#U042d#U2510#U0447#U042e#U043c#U0449#U0427#U2524#U0445#U041f#U0421#U0449#U0433#U0429#U0444#U2551#U0416_urlgot_279.avi
#         File name too long
# error:  cannot create ./xclip_fight/train/Fight/#U0447#U255c#U0421#U0445#U0420#U0437#U0449#U0411#U043d#U0445#U2591#U041f#U0446#U2556#U2556#U0446#U2556#U2556#U0446#U0419#U0423#U0446#U042e#U2562#U044f#U255d#U041c#U0447#U042b#U0421#U0446#U041e#U0437#U0445#U0415#U0438#U0447#U0438#U041b#U0446#U041b#U041d#U0446#U0421#U0414_urlgot_317.avi
#         File name too long

# %%
import pathlib

dataset_root_path = "./xclip_fight/"
dataset_root_path = pathlib.Path(dataset_root_path)
video_count_train = len(list(dataset_root_path.glob("train/*/*.avi")))
video_count_val = len(list(dataset_root_path.glob("val/*/*.avi")))
video_count_test = len(list(dataset_root_path.glob("test/*/*.avi")))
video_total = video_count_train + video_count_val + video_count_test
print(f"Total videos: {video_total}")
# Out:
# Total videos: 641

# %% [markdown]
# Let's now count the number of total videos we have.

# %%
train_paths = list(dataset_root_path.glob("train/*/*.avi"))
val_paths = list(dataset_root_path.glob("val/*/*.avi"))

# %%
import random
import os

# Function for deleting videos with error handling
def delete_videos(paths_to_delete):
    for path in paths_to_delete:
        try:
            os.remove(path)
            print(f"Deleted: {path}")
        except OSError as error:
            print(f"Error deleting {path}: {error}")

# Delete videos from train directory
half_to_delete = len(train_paths) // 4
train_paths_to_delete = random.sample(train_paths, half_to_delete)
delete_videos(train_paths_to_delete)

# Delete videos from val directory
half_to_delete = len(val_paths) // 4
val_paths_to_delete = random.sample(val_paths, half_to_delete)
delete_videos(val_paths_to_delete)
# Out:
# Error deleting xclip_fight/train/No Fight/gUYfrLHe_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/gUYfrLHe_0.avi'
# Error deleting xclip_fight/train/No Fight/H_VQJU0Bqpc_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/H_VQJU0Bqpc_0.avi'
# Error deleting xclip_fight/train/Fight/DC10fyQgNqo_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/DC10fyQgNqo_0.avi'
# Deleted: xclip_fight/train/Fight/PFw7SeFOD04_1.avi
# Error deleting xclip_fight/train/Fight/9ErNHIovPDI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/9ErNHIovPDI_0.avi'
# Error deleting xclip_fight/train/Fight/GhZRf4GIw0w_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/GhZRf4GIw0w_0.avi'
# Error deleting xclip_fight/train/No Fight/Y-TiUAODEYw_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/Y-TiUAODEYw_1.avi'
# Deleted: xclip_fight/train/No Fight/rYE6iUUF_0.avi
# Error deleting xclip_fight/train/No Fight/18xQQOv5_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/18xQQOv5_0.avi'
# Error deleting xclip_fight/train/No Fight/hrBh5x_3hW0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/hrBh5x_3hW0_0.avi'
# Error deleting xclip_fight/train/No Fight/s83GiLts_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/s83GiLts_0.avi'
# Error deleting xclip_fight/train/Fight/_q5Nwh4Z6ao_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/_q5Nwh4Z6ao_2.avi'
# Error deleting xclip_fight/train/No Fight/yvNawsRf_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/yvNawsRf_0.avi'
# Error deleting xclip_fight/train/No Fight/U1Z1bVRt_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/U1Z1bVRt_0.avi'
# Deleted: xclip_fight/train/No Fight/WCbsjDUV_0.avi
# Error deleting xclip_fight/train/Fight/RTDSFDSA_677.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/RTDSFDSA_677.avi'
# Error deleting xclip_fight/train/No Fight/zHRkgmIT_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/zHRkgmIT_0.avi'
# Error deleting xclip_fight/train/No Fight/ULiIpQ6s_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/ULiIpQ6s_0.avi'
# Deleted: xclip_fight/train/No Fight/on2HIPgB_0.avi
# Error deleting xclip_fight/train/No Fight/gR4OsEPl894_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/gR4OsEPl894_2.avi'
# Error deleting xclip_fight/train/Fight/SXd2yu2LHv0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/SXd2yu2LHv0_0.avi'
# Error deleting xclip_fight/train/No Fight/SJ9WphBI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/SJ9WphBI_0.avi'
# Deleted: xclip_fight/train/No Fight/H1AzC-GyKto_1.avi
# Error deleting xclip_fight/train/No Fight/jTbvVbkUaPM_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/jTbvVbkUaPM_1.avi'
# Error deleting xclip_fight/train/No Fight/14YZVngQ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/14YZVngQ_0.avi'
# Error deleting xclip_fight/train/Fight/4yTlGiDoxBo_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/4yTlGiDoxBo_1.avi'
# Error deleting xclip_fight/train/Fight/zuCTuKvj_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/zuCTuKvj_3.avi'
# Deleted: xclip_fight/train/Fight/xrlCdUaagHY_0.avi
# Error deleting xclip_fight/train/Fight/Gr3ikl6A2bE_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/Gr3ikl6A2bE_1.avi'
# Error deleting xclip_fight/train/No Fight/8pKKdS7rhXo_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/8pKKdS7rhXo_0.avi'
# Error deleting xclip_fight/train/Fight/lmfaDmCCRoY_7.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/lmfaDmCCRoY_7.avi'
# Deleted: xclip_fight/train/No Fight/hrBh5x_3hW0_1.avi
# Error deleting xclip_fight/train/No Fight/kMI2JME3Aag_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/kMI2JME3Aag_0.avi'
# Error deleting xclip_fight/train/Fight/vQKHxtrdEHM_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/vQKHxtrdEHM_0.avi'
# Error deleting xclip_fight/train/No Fight/gk0v57Xn_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/gk0v57Xn_0.avi'
# Error deleting xclip_fight/train/No Fight/iRnSE1TL_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/iRnSE1TL_0.avi'
# Error deleting xclip_fight/train/Fight/6Dej3-k3MRE_4.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/6Dej3-k3MRE_4.avi'
# Deleted: xclip_fight/train/Fight/RYFG_779.avi
# Deleted: xclip_fight/train/No Fight/Assault005_x264_1.avi
# Deleted: xclip_fight/train/Fight/tILABXoHE7s_0.avi
# Error deleting xclip_fight/train/Fight/POGFN_429.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/POGFN_429.avi'
# Error deleting xclip_fight/train/Fight/i5xJxtv4gXs_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/i5xJxtv4gXs_1.avi'
# Error deleting xclip_fight/train/Fight/BpargJW29Wo_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/BpargJW29Wo_2.avi'
# Deleted: xclip_fight/train/Fight/vQKHxtrdEHM_9.avi
# Error deleting xclip_fight/train/Fight/6TDF_13.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/6TDF_13.avi'
# Deleted: xclip_fight/train/No Fight/RfqBhe5z_0.avi
# Deleted: xclip_fight/train/No Fight/X14e9Fwxa8w_0.avi
# Deleted: xclip_fight/train/No Fight/dkTzP0SB_0.avi
# Error deleting xclip_fight/train/No Fight/K4700BuM_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/K4700BuM_0.avi'
# Error deleting xclip_fight/train/No Fight/fvtpgsrF_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/fvtpgsrF_0.avi'
# Error deleting xclip_fight/train/No Fight/uu3SB2L1_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/uu3SB2L1_0.avi'
# Error deleting xclip_fight/train/Fight/lUjx4FXvv34_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/lUjx4FXvv34_1.avi'
# Deleted: xclip_fight/train/Fight/U-rD98WfBYs_0.avi
# Error deleting xclip_fight/train/Fight/POGFN_432.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/POGFN_432.avi'
# Deleted: xclip_fight/train/Fight/YUOfgfuh_1.avi
# Error deleting xclip_fight/train/No Fight/fBwfFDcgJlk_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/fBwfFDcgJlk_0.avi'
# Error deleting xclip_fight/train/Fight/bdZ7ubago6I_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/bdZ7ubago6I_1.avi'
# Error deleting xclip_fight/train/No Fight/CfPgoKqk_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/CfPgoKqk_0.avi'
# Error deleting xclip_fight/train/Fight/fSE4L50n_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/fSE4L50n_0.avi'
# Error deleting xclip_fight/train/Fight/erwyrhd_339.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/erwyrhd_339.avi'
# Deleted: xclip_fight/train/Fight/lmfaDmCCRoY_3.avi
# Error deleting xclip_fight/train/Fight/sadsa_956.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/sadsa_956.avi'
# Error deleting xclip_fight/train/Fight/3CQi0ZCCHvc_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/3CQi0ZCCHvc_1.avi'
# Deleted: xclip_fight/train/No Fight/16O0PIQP_0.avi
# Deleted: xclip_fight/train/No Fight/6Dej3-k3MRE_0.avi
# Deleted: xclip_fight/train/No Fight/11vr9Jho_0.avi
# Error deleting xclip_fight/train/No Fight/itstEXVr_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/itstEXVr_0.avi'
# Error deleting xclip_fight/train/No Fight/Assault011_x264_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/Assault011_x264_0.avi'
# Deleted: xclip_fight/train/Fight/trhfd_1016.avi
# Error deleting xclip_fight/train/Fight/E2gqgFNyPL8_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/E2gqgFNyPL8_0.avi'
# Deleted: xclip_fight/train/No Fight/BUjGBAPb_0.avi
# Error deleting xclip_fight/train/Fight/b6XfVAZC9Zs_4.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/b6XfVAZC9Zs_4.avi'
# Error deleting xclip_fight/train/No Fight/VpnCjE1l_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/VpnCjE1l_0.avi'
# Deleted: xclip_fight/train/No Fight/Q876qiBJYfA_0.avi
# Deleted: xclip_fight/train/No Fight/TYsebroPeGY_1.avi
# Error deleting xclip_fight/train/No Fight/3qsou7p57Nk_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/3qsou7p57Nk_0.avi'
# Deleted: xclip_fight/train/No Fight/8SWZq5we_fk_2.avi
# Error deleting xclip_fight/train/No Fight/1Ytq2moWGdw_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/1Ytq2moWGdw_0.avi'
# Error deleting xclip_fight/train/Fight/dxzvtJ4gPC0_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/dxzvtJ4gPC0_1.avi'
# Deleted: xclip_fight/train/Fight/u2Lkzfb0_0.avi
# Error deleting xclip_fight/train/No Fight/KxOHVkVQ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/KxOHVkVQ_0.avi'
# Error deleting xclip_fight/train/No Fight/LLo_TXIz5-g_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/LLo_TXIz5-g_0.avi'
# Deleted: xclip_fight/train/No Fight/3qsou7p57Nk_1.avi
# Deleted: xclip_fight/train/No Fight/sPd5Wmkc_0.avi
# Error deleting xclip_fight/train/Fight/ug2tQMG8DC0_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/ug2tQMG8DC0_1.avi'
# Error deleting xclip_fight/train/No Fight/oVMhWJIpHnc_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/oVMhWJIpHnc_0.avi'
# Deleted: xclip_fight/train/No Fight/tzdvtHL7Akk_1.avi
# Deleted: xclip_fight/train/Fight/YL-qwpTMjzk_0.avi
# Deleted: xclip_fight/train/Fight/7LnoFKSl2rs_0.avi
# Error deleting xclip_fight/train/Fight/u-29uYuR2cg_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/u-29uYuR2cg_0.avi'
# Deleted: xclip_fight/train/No Fight/0YbzxGPE_0.avi
# Error deleting xclip_fight/train/Fight/-1l5631l3fg_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/-1l5631l3fg_0.avi'
# Error deleting xclip_fight/train/Fight/z1WyVUv8_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/z1WyVUv8_2.avi'
# Error deleting xclip_fight/train/Fight/wetyh_1223.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/wetyh_1223.avi'
# Deleted: xclip_fight/train/Fight/20130506 05_58 #U0448#U0427#U042d#U0444#U2551#U2551 #U0449#U2557#U0421#U0446#U042e#U042d_37.avi
# Deleted: xclip_fight/train/No Fight/oDWNiATJ_0.avi
# Error deleting xclip_fight/train/Fight/PlHzsigAFas_9.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/PlHzsigAFas_9.avi'
# Error deleting xclip_fight/train/Fight/E0Huf4Qi0JE_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/E0Huf4Qi0JE_0.avi'
# Error deleting xclip_fight/train/No Fight/4jZvTj4j_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/4jZvTj4j_0.avi'
# Error deleting xclip_fight/train/Fight/GafFu4IZtIA_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/GafFu4IZtIA_1.avi'
# Error deleting xclip_fight/train/Fight/DHhyNrXr_5.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/DHhyNrXr_5.avi'
# Error deleting xclip_fight/train/No Fight/kOp57sQKMPY_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/kOp57sQKMPY_0.avi'
# Deleted: xclip_fight/train/No Fight/az7WDDFT_0.avi
# Error deleting xclip_fight/train/No Fight/rSGIFH7n_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/rSGIFH7n_0.avi'
# Error deleting xclip_fight/train/No Fight/Assault009_x264_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/Assault009_x264_1.avi'
# Error deleting xclip_fight/train/No Fight/WW8zIoiZ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/WW8zIoiZ_0.avi'
# Error deleting xclip_fight/train/No Fight/oMZpqizQ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/oMZpqizQ_0.avi'
# Deleted: xclip_fight/train/Fight/6Dej3-k3MRE_1.avi
# Deleted: xclip_fight/train/Fight/e4U3gEDEB58_0.avi
# Deleted: xclip_fight/train/Fight/0_DzLlklZa0_3.avi
# Error deleting xclip_fight/train/No Fight/RFAA8QO7_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/RFAA8QO7_0.avi'
# Deleted: xclip_fight/train/No Fight/OAFsSiyX_0.avi
# Deleted: xclip_fight/train/Fight/GafFu4IZtIA_7.avi
# Deleted: xclip_fight/train/Fight/_6-B11R9FJM_2.avi
# Deleted: xclip_fight/train/Fight/24E0xYYUz44_0.avi
# Error deleting xclip_fight/train/Fight/zuCTuKvj_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/zuCTuKvj_2.avi'
# Deleted: xclip_fight/train/Fight/wetrew_1195.avi
# Error deleting xclip_fight/train/Fight/GafFu4IZtIA_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/GafFu4IZtIA_2.avi'
# Error deleting xclip_fight/train/No Fight/dOM7frJMFbc_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/dOM7frJMFbc_3.avi'
# Error deleting xclip_fight/train/Fight/dKqbUbuRxB4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/dKqbUbuRxB4_0.avi'
# Error deleting xclip_fight/train/Fight/dHEI4OkhC64_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/dHEI4OkhC64_0.avi'
# Error deleting xclip_fight/train/Fight/bzw-HKuuQbg_6.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/bzw-HKuuQbg_6.avi'
# Deleted: xclip_fight/train/Fight/ZVPU5c95_0.avi
# Deleted: xclip_fight/train/Fight/X6V5o-uCYF4_2.avi
# Error deleting xclip_fight/train/Fight/OAfV0xPIhZw_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/OAfV0xPIhZw_3.avi'
# Error deleting xclip_fight/train/Fight/gHcG_c1i4uE_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/gHcG_c1i4uE_0.avi'
# Error deleting xclip_fight/train/No Fight/VnDOPZls_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/VnDOPZls_0.avi'
# Error deleting xclip_fight/train/No Fight/qmvilMkD57M_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/qmvilMkD57M_1.avi'
# Deleted: xclip_fight/train/No Fight/UQ42UqFJ_0.avi
# Error deleting xclip_fight/train/Fight/F7W6PQ3V3y8_10.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/F7W6PQ3V3y8_10.avi'
# Error deleting xclip_fight/train/No Fight/BpargJW29Wo_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/BpargJW29Wo_0.avi'
# Deleted: xclip_fight/train/No Fight/aKgSasWRJ2s_0.avi
# Error deleting xclip_fight/train/Fight/lUjx4FXvv34_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/lUjx4FXvv34_0.avi'
# Error deleting xclip_fight/train/No Fight/b9I5dDvH_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/b9I5dDvH_0.avi'
# Error deleting xclip_fight/train/Fight/1tU4kxa51vw_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/1tU4kxa51vw_1.avi'
# Deleted: xclip_fight/train/No Fight/UvLAudRA91Y_1.avi
# Error deleting xclip_fight/train/No Fight/gEODOSeI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/gEODOSeI_0.avi'
# Deleted: xclip_fight/train/No Fight/0vasozvJYvk_2.avi
# Error deleting xclip_fight/train/No Fight/DTq6Gu30-uA_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/DTq6Gu30-uA_1.avi'
# Error deleting xclip_fight/train/No Fight/e4U3gEDEB58_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/e4U3gEDEB58_0.avi'
# Deleted: xclip_fight/train/No Fight/BOt8ZMpM_0.avi
# Deleted: xclip_fight/train/No Fight/H_VQJU0Bqpc_3.avi
# Error deleting xclip_fight/train/No Fight/cVYo5yT2_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/cVYo5yT2_0.avi'
# Deleted: xclip_fight/train/No Fight/9uvZbSsy_0.avi
# Error deleting xclip_fight/train/Fight/aIg9Yb0O7Hg_5.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/aIg9Yb0O7Hg_5.avi'
# Error deleting xclip_fight/train/No Fight/DIsQwAdR8MI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/DIsQwAdR8MI_0.avi'
# Deleted: xclip_fight/train/Fight/ECoMcgjR_0.avi
# Error deleting xclip_fight/train/No Fight/ep1_I0f-u7g_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/ep1_I0f-u7g_1.avi'
# Error deleting xclip_fight/train/Fight/p19HiyCX7EQ_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/p19HiyCX7EQ_2.avi'
# Error deleting xclip_fight/train/No Fight/FWsNU4WI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/FWsNU4WI_0.avi'
# Deleted: xclip_fight/train/No Fight/5RayT2Vy0EA_1.avi
# Error deleting xclip_fight/train/No Fight/BOLcNZ5O_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/BOLcNZ5O_0.avi'
# Deleted: xclip_fight/train/No Fight/Assault009_x264_0.avi
# Deleted: xclip_fight/train/No Fight/9GFNxpur_0.avi
# Deleted: xclip_fight/train/No Fight/_fPfNbHM16M_0.avi
# Error deleting xclip_fight/train/Fight/truutrdf_1084.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/truutrdf_1084.avi'
# Deleted: xclip_fight/train/No Fight/_q5Nwh4Z6ao_6.avi
# Deleted: xclip_fight/train/Fight/K_7hT4N2QCE_1.avi
# Error deleting xclip_fight/train/No Fight/l4gqDHx9_dI_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/l4gqDHx9_dI_1.avi'
# Error deleting xclip_fight/train/Fight/PTy2vx8Ejas_5.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/PTy2vx8Ejas_5.avi'
# Error deleting xclip_fight/train/Fight/fwEk96k8g_I_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/fwEk96k8g_I_3.avi'
# Error deleting xclip_fight/train/Fight/0H2s9UJcNJ0_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/0H2s9UJcNJ0_2.avi'
# Deleted: xclip_fight/train/No Fight/gI4u3PwG_0.avi
# Deleted: xclip_fight/train/No Fight/9Jss3rP1_0.avi
# Deleted: xclip_fight/train/No Fight/1tU4kxa51vw_0.avi
# Error deleting xclip_fight/train/Fight/_q5Nwh4Z6ao_11.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/_q5Nwh4Z6ao_11.avi'
# Error deleting xclip_fight/train/Fight/dOM7frJMFbc_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/dOM7frJMFbc_2.avi'
# Error deleting xclip_fight/train/No Fight/24E0xYYUz44_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/24E0xYYUz44_1.avi'
# Error deleting xclip_fight/train/No Fight/TuWan04E3gQ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/TuWan04E3gQ_0.avi'
# Deleted: xclip_fight/train/No Fight/0QSeuqzpcOQ_0.avi
# Error deleting xclip_fight/train/Fight/jCD7lUJQ7Xc_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/jCD7lUJQ7Xc_1.avi'
# Deleted: xclip_fight/train/Fight/videoplayback (2)_66.avi
# Deleted: xclip_fight/train/Fight/Jq8neqBlL2Y_2.avi
# Error deleting xclip_fight/train/Fight/DTq6Gu30-uA_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/DTq6Gu30-uA_1.avi'
# Error deleting xclip_fight/train/No Fight/X3mPJLe9_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/X3mPJLe9_0.avi'
# Error deleting xclip_fight/train/No Fight/DThokDTW_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/DThokDTW_0.avi'
# Deleted: xclip_fight/train/No Fight/DRlOjUNi_0.avi
# Deleted: xclip_fight/train/No Fight/kMI2JME3Aag_3.avi
# Error deleting xclip_fight/train/No Fight/aGfwZ3E4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/aGfwZ3E4_0.avi'
# Deleted: xclip_fight/train/No Fight/1O4KGHbRt3M_1.avi
# Deleted: xclip_fight/train/No Fight/ljLg4lFbS0Y_0.avi
# Deleted: xclip_fight/train/Fight/T56HlypCEyU_0.avi
# Deleted: xclip_fight/train/No Fight/7KXPekwe_0.avi
# Deleted: xclip_fight/train/No Fight/Assault010_x264_0.avi
# Deleted: xclip_fight/train/Fight/BpargJW29Wo_3.avi
# Deleted: xclip_fight/train/Fight/X6V5o-uCYF4_0.avi
# Error deleting xclip_fight/train/No Fight/Assault005_x264_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/Assault005_x264_0.avi'
# Error deleting xclip_fight/train/No Fight/hP8CJJcx_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/hP8CJJcx_0.avi'
# Error deleting xclip_fight/train/No Fight/9haGKtHJ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/9haGKtHJ_0.avi'
# Deleted: xclip_fight/train/Fight/jTbvVbkUaPM_4.avi
# Deleted: xclip_fight/train/No Fight/GqDA8E4j_0.avi
# Deleted: xclip_fight/train/Fight/1dsLuL5Lvbc_3.avi
# Error deleting xclip_fight/train/No Fight/KOaUqaC8_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/KOaUqaC8_0.avi'
# Deleted: xclip_fight/train/Fight/bd48s5BpoGY_0.avi
# Deleted: xclip_fight/train/No Fight/JwfajujK_0.avi
# Error deleting xclip_fight/train/No Fight/4RgIlSIB_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/4RgIlSIB_0.avi'
# Deleted: xclip_fight/train/No Fight/d_93UNyiVM4_0.avi
# Error deleting xclip_fight/train/Fight/CBfRtxkO1bE_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/CBfRtxkO1bE_2.avi'
# Error deleting xclip_fight/train/Fight/a7D2i0HTXGM_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/a7D2i0HTXGM_2.avi'
# Error deleting xclip_fight/train/Fight/gnBmOf7v_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/gnBmOf7v_0.avi'
# Error deleting xclip_fight/train/No Fight/ev8va5uR_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/ev8va5uR_0.avi'
# Deleted: xclip_fight/train/Fight/dt8YUGoOSgQ_1.avi
# Error deleting xclip_fight/train/No Fight/LbYQs9oA_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/LbYQs9oA_0.avi'
# Deleted: xclip_fight/train/No Fight/NPeKBgURcxI_0.avi
# Error deleting xclip_fight/train/Fight/_6-B11R9FJM_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/_6-B11R9FJM_1.avi'
# Error deleting xclip_fight/train/No Fight/uz4dXoN5_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/uz4dXoN5_0.avi'
# Error deleting xclip_fight/train/Fight/b6XfVAZC9Zs_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/b6XfVAZC9Zs_2.avi'
# Error deleting xclip_fight/train/No Fight/qrBAhb8K_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/qrBAhb8K_0.avi'
# Error deleting xclip_fight/train/Fight/1XFiS6Lt_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/1XFiS6Lt_0.avi'
# Error deleting xclip_fight/train/Fight/dP20avzQAf8_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/dP20avzQAf8_1.avi'
# Deleted: xclip_fight/train/No Fight/nj9Rc3lY_0.avi
# Deleted: xclip_fight/train/No Fight/TSHiCcMS_0.avi
# Error deleting xclip_fight/train/No Fight/okA8k7rF_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/okA8k7rF_0.avi'
# Error deleting xclip_fight/train/Fight/FZDDNtcaBcw_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/FZDDNtcaBcw_0.avi'
# Error deleting xclip_fight/train/Fight/3kpviz7lAMY_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/3kpviz7lAMY_0.avi'
# Error deleting xclip_fight/train/No Fight/oLs9ckoV_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/oLs9ckoV_0.avi'
# Error deleting xclip_fight/train/No Fight/pinuwjwm_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/pinuwjwm_0.avi'
# Deleted: xclip_fight/train/Fight/7R1m3V8C30g_2.avi
# Error deleting xclip_fight/train/No Fight/tILABXoHE7s_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/tILABXoHE7s_0.avi'
# Error deleting xclip_fight/train/No Fight/X0fP5VQMrbg_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/X0fP5VQMrbg_1.avi'
# Deleted: xclip_fight/train/Fight/oVMhWJIpHnc_0.avi
# Deleted: xclip_fight/train/Fight/HW48LUZKOL4_4.avi
# Error deleting xclip_fight/train/No Fight/5RayT2Vy0EA_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/5RayT2Vy0EA_2.avi'
# Error deleting xclip_fight/train/No Fight/aKK0B4kpKZA_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/aKK0B4kpKZA_0.avi'
# Error deleting xclip_fight/train/Fight/3kpviz7lAMY_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/3kpviz7lAMY_1.avi'
# Deleted: xclip_fight/train/Fight/cy1gi3ZJb_c_3.avi
# Error deleting xclip_fight/train/Fight/kExp3yhspR0_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/kExp3yhspR0_3.avi'
# Error deleting xclip_fight/train/Fight/PTy2vx8Ejas_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/PTy2vx8Ejas_0.avi'
# Deleted: xclip_fight/train/Fight/o9sRXy5r_2.avi
# Error deleting xclip_fight/train/Fight/cBNVcBk3rjg_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/cBNVcBk3rjg_3.avi'
# Deleted: xclip_fight/train/Fight/4RqDG4I4iAk_0.avi
# Deleted: xclip_fight/train/No Fight/YC51sSdT_0.avi
# Deleted: xclip_fight/train/Fight/PlHzsigAFas_4.avi
# Error deleting xclip_fight/train/Fight/JRL5Vvql_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/JRL5Vvql_0.avi'
# Error deleting xclip_fight/train/Fight/aKgSasWRJ2s_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/aKgSasWRJ2s_3.avi'
# Error deleting xclip_fight/train/Fight/BCVBVC_263.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/BCVBVC_263.avi'
# Error deleting xclip_fight/train/Fight/ZnRk8nWJ548_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/ZnRk8nWJ548_0.avi'
# Deleted: xclip_fight/train/Fight/Suv_mMs8J9g_0.avi
# Error deleting xclip_fight/train/Fight/NPeKBgURcxI_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/NPeKBgURcxI_2.avi'
# Error deleting xclip_fight/train/No Fight/551_wlV44GU_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/551_wlV44GU_0.avi'
# Error deleting xclip_fight/train/No Fight/7icHwpC_d44_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/7icHwpC_d44_0.avi'
# Deleted: xclip_fight/train/No Fight/IynvwHe9W3U_3.avi
# Error deleting xclip_fight/train/Fight/EtRfZ2KP_5.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/EtRfZ2KP_5.avi'
# Error deleting xclip_fight/train/No Fight/LLo_TXIz5-g_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/LLo_TXIz5-g_1.avi'
# Deleted: xclip_fight/train/Fight/RYFG_775.avi
# Deleted: xclip_fight/train/Fight/H1AzC-GyKto_0.avi
# Deleted: xclip_fight/train/No Fight/Xr0T6ylW_0.avi
# Deleted: xclip_fight/train/No Fight/kFbpQrq2_0.avi
# Error deleting xclip_fight/train/No Fight/6mrIIcAQ2fI_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/6mrIIcAQ2fI_1.avi'
# Deleted: xclip_fight/train/Fight/BCVBVC_264.avi
# Error deleting xclip_fight/train/Fight/91TniI0y_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/91TniI0y_0.avi'
# Deleted: xclip_fight/train/Fight/s3gaPKuW_1.avi
# Error deleting xclip_fight/train/Fight/_q5Nwh4Z6ao_10.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/_q5Nwh4Z6ao_10.avi'
# Error deleting xclip_fight/train/Fight/uKFI67bUzfg_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/uKFI67bUzfg_0.avi'
# Error deleting xclip_fight/train/No Fight/iquSbj5Wqj0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/iquSbj5Wqj0_0.avi'
# Error deleting xclip_fight/train/Fight/PFw7SeFOD04_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/PFw7SeFOD04_3.avi'
# Error deleting xclip_fight/train/Fight/Wby1vUy8aYI_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/Wby1vUy8aYI_2.avi'
# Deleted: xclip_fight/train/No Fight/YJvuxdWs_0.avi
# Deleted: xclip_fight/train/No Fight/umOs1WLBkuo_2.avi
# Error deleting xclip_fight/train/No Fight/oDGm-DOOyI4_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/oDGm-DOOyI4_1.avi'
# Error deleting xclip_fight/train/No Fight/F7W6PQ3V3y8_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/F7W6PQ3V3y8_0.avi'
# Deleted: xclip_fight/train/Fight/a2qLzOu_n0s_3.avi
# Error deleting xclip_fight/train/Fight/fwEk96k8g_I_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/fwEk96k8g_I_2.avi'
# Error deleting xclip_fight/train/Fight/uXf4C-YwbtM_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/uXf4C-YwbtM_3.avi'
# Error deleting xclip_fight/train/No Fight/R2x2rOWh_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/R2x2rOWh_0.avi'
# Deleted: xclip_fight/train/No Fight/qIRZ4SMf_0.avi
# Deleted: xclip_fight/train/Fight/QkqaGJ9x_2.avi
# Error deleting xclip_fight/train/Fight/videoplayback (2)_74.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/videoplayback (2)_74.avi'
# Deleted: xclip_fight/train/Fight/G3E1YP6agWs_1.avi
# Deleted: xclip_fight/train/No Fight/i5xJxtv4gXs_1.avi
# Error deleting xclip_fight/train/Fight/QUGT4a6qcJs_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/QUGT4a6qcJs_0.avi'
# Deleted: xclip_fight/train/Fight/EtRfZ2KP_2.avi
# Error deleting xclip_fight/train/No Fight/xxIkl4Ue_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/xxIkl4Ue_0.avi'
# Error deleting xclip_fight/train/Fight/H1AzC-GyKto_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/H1AzC-GyKto_1.avi'
# Error deleting xclip_fight/train/No Fight/C7Ty4ui5_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/C7Ty4ui5_0.avi'
# Error deleting xclip_fight/train/Fight/0NWz-01A2yk_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/0NWz-01A2yk_1.avi'
# Error deleting xclip_fight/train/No Fight/JxpNuQop_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/JxpNuQop_0.avi'
# Error deleting xclip_fight/train/No Fight/jbSCSexU_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/jbSCSexU_0.avi'
# Error deleting xclip_fight/train/No Fight/1ahhhDBQHxg_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/1ahhhDBQHxg_0.avi'
# Error deleting xclip_fight/train/Fight/Kx5lWLPZ0Y0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/Kx5lWLPZ0Y0_0.avi'
# Error deleting xclip_fight/train/No Fight/0NqPsSHdri8_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/0NqPsSHdri8_0.avi'
# Error deleting xclip_fight/train/No Fight/cPeNUm31_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/cPeNUm31_0.avi'
# Error deleting xclip_fight/train/No Fight/fJkWWpNB_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/fJkWWpNB_0.avi'
# Error deleting xclip_fight/train/No Fight/5CwYc67y_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/5CwYc67y_0.avi'
# Deleted: xclip_fight/train/Fight/NpznjZe7A2M_0.avi
# Deleted: xclip_fight/train/Fight/p19HiyCX7EQ_1.avi
# Error deleting xclip_fight/train/No Fight/aQysMqg0K7M_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/aQysMqg0K7M_3.avi'
# Deleted: xclip_fight/train/No Fight/MX77f2TD_0.avi
# Error deleting xclip_fight/train/Fight/ThiaJUQ8_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/ThiaJUQ8_1.avi'
# Deleted: xclip_fight/train/Fight/NxtwlqSnLbY_4.avi
# Error deleting xclip_fight/train/No Fight/HVSv9sgz2ZI_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/HVSv9sgz2ZI_1.avi'
# Error deleting xclip_fight/train/No Fight/uLGOlxvv_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/uLGOlxvv_0.avi'
# Error deleting xclip_fight/train/No Fight/xtA4owfr_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/xtA4owfr_0.avi'
# Deleted: xclip_fight/train/Fight/JRL5Vvql_1.avi
# Deleted: xclip_fight/train/Fight/bqZo64e6_1.avi
# Error deleting xclip_fight/train/Fight/bzw-HKuuQbg_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/bzw-HKuuQbg_2.avi'
# Deleted: xclip_fight/train/Fight/gR4OsEPl894_2.avi
# Error deleting xclip_fight/train/Fight/QaIY5Au8yOc_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/QaIY5Au8yOc_1.avi'
# Error deleting xclip_fight/train/Fight/l4gqDHx9_dI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/l4gqDHx9_dI_0.avi'
# Deleted: xclip_fight/train/No Fight/uyeWsodv_0.avi
# Error deleting xclip_fight/train/No Fight/UWmcbEyn_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/UWmcbEyn_0.avi'
# Deleted: xclip_fight/train/No Fight/g3QdfSDk_0.avi
# Deleted: xclip_fight/train/No Fight/0_DzLlklZa0_2.avi
# Deleted: xclip_fight/train/No Fight/xKq3hlefCUI_0.avi
# Deleted: xclip_fight/train/Fight/4yTlGiDoxBo_5.avi
# Deleted: xclip_fight/train/Fight/lmfaDmCCRoY_5.avi
# Error deleting xclip_fight/train/No Fight/0H2s9UJcNJ0_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/0H2s9UJcNJ0_1.avi'
# Error deleting xclip_fight/train/No Fight/wNTaSOXj_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/wNTaSOXj_0.avi'
# Error deleting xclip_fight/train/Fight/ug2tQMG8DC0_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/ug2tQMG8DC0_2.avi'
# Deleted: xclip_fight/train/Fight/mRqg-WXiR7Q_1.avi
# Error deleting xclip_fight/train/No Fight/3Vw7MoNBgx4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/3Vw7MoNBgx4_0.avi'
# Error deleting xclip_fight/train/No Fight/RbpXgk5M1S0_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/RbpXgk5M1S0_1.avi'
# Deleted: xclip_fight/train/Fight/4yTlGiDoxBo_2.avi
# Error deleting xclip_fight/train/Fight/tIvvuvuJFYc_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/tIvvuvuJFYc_0.avi'
# Deleted: xclip_fight/train/No Fight/Y-TiUAODEYw_2.avi
# Error deleting xclip_fight/train/Fight/JPIeYvRgo6I_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/JPIeYvRgo6I_0.avi'
# Error deleting xclip_fight/train/No Fight/OCseFRss_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/OCseFRss_0.avi'
# Deleted: xclip_fight/train/Fight/oW8ySS0rN4Y_0.avi
# Error deleting xclip_fight/train/No Fight/zWrAqXFn_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/zWrAqXFn_0.avi'
# Error deleting xclip_fight/train/Fight/RTDSFDSA_674.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/RTDSFDSA_674.avi'
# Deleted: xclip_fight/train/No Fight/yDKfgkb2_0.avi
# Error deleting xclip_fight/train/No Fight/uhTalZ00_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/uhTalZ00_0.avi'
# Deleted: xclip_fight/train/Fight/DC10fyQgNqo_2.avi
# Error deleting xclip_fight/train/Fight/3OKArbzg1uc_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/3OKArbzg1uc_3.avi'
# Deleted: xclip_fight/train/No Fight/HVSv9sgz2ZI_0.avi
# Error deleting xclip_fight/train/No Fight/Wby1vUy8aYI_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/Wby1vUy8aYI_0.avi'
# Error deleting xclip_fight/train/Fight/sadsa_957.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/sadsa_957.avi'
# Error deleting xclip_fight/train/Fight/24E0xYYUz44_4.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/24E0xYYUz44_4.avi'
# Error deleting xclip_fight/train/Fight/_TwPzPRK7dc_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/_TwPzPRK7dc_0.avi'
# Deleted: xclip_fight/train/Fight/JwTPruSFTjk_0.avi
# Deleted: xclip_fight/train/Fight/9U8J4abJGDg_0.avi
# Error deleting xclip_fight/train/No Fight/ljLg4lFbS0Y_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/ljLg4lFbS0Y_1.avi'
# Deleted: xclip_fight/train/No Fight/AG0ofjSP_0.avi
# Deleted: xclip_fight/train/No Fight/jj9SJGft_0.avi
# Deleted: xclip_fight/train/Fight/PlHzsigAFas_8.avi
# Error deleting xclip_fight/train/No Fight/HYkbCvPj_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/HYkbCvPj_0.avi'
# Error deleting xclip_fight/train/No Fight/a7gBQaAFEtw_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/a7gBQaAFEtw_2.avi'
# Deleted: xclip_fight/train/No Fight/J2rsCgMC_0.avi
# Deleted: xclip_fight/train/No Fight/RNOSWjgC_0.avi
# Error deleting xclip_fight/train/Fight/Fc45rUKM_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/Fc45rUKM_2.avi'
# Deleted: xclip_fight/train/No Fight/Tzn3HwZD_0.avi
# Error deleting xclip_fight/train/No Fight/0H2s9UJcNJ0_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/0H2s9UJcNJ0_2.avi'
# Error deleting xclip_fight/train/Fight/Pe1uIhp4dAQ_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/Pe1uIhp4dAQ_3.avi'
# Error deleting xclip_fight/train/No Fight/UuMYxOYm_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/UuMYxOYm_0.avi'
# Deleted: xclip_fight/train/No Fight/HW48LUZKOL4_0.avi
# Error deleting xclip_fight/train/No Fight/tILABXoHE7s_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/tILABXoHE7s_1.avi'
# Error deleting xclip_fight/train/Fight/R1A_AxUKosk_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/R1A_AxUKosk_3.avi'
# Error deleting xclip_fight/train/Fight/iquSbj5Wqj0_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/iquSbj5Wqj0_1.avi'
# Error deleting xclip_fight/train/No Fight/oAeudqZD_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/oAeudqZD_0.avi'
# Error deleting xclip_fight/train/Fight/DHhyNrXr_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/DHhyNrXr_2.avi'
# Error deleting xclip_fight/train/No Fight/fwEk96k8g_I_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/fwEk96k8g_I_0.avi'
# Error deleting xclip_fight/train/Fight/mX4cQM1xMFc_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/mX4cQM1xMFc_0.avi'
# Deleted: xclip_fight/train/Fight/asdasda_113.avi
# Error deleting xclip_fight/train/Fight/Fc45rUKM_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/Fc45rUKM_3.avi'
# Deleted: xclip_fight/train/Fight/erwyrhd_338.avi
# Error deleting xclip_fight/train/Fight/kLHNW0uRutY_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/kLHNW0uRutY_3.avi'
# Error deleting xclip_fight/train/No Fight/FPU7QpO4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/FPU7QpO4_0.avi'
# Error deleting xclip_fight/train/No Fight/9N4HikpX_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/9N4HikpX_0.avi'
# Deleted: xclip_fight/train/Fight/3SS0E4SmTk8_0.avi
# Error deleting xclip_fight/train/No Fight/oByKgGBL_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/oByKgGBL_0.avi'
# Deleted: xclip_fight/train/Fight/SjJEt0drQZs_0.avi
# Error deleting xclip_fight/train/Fight/dxzvtJ4gPC0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/dxzvtJ4gPC0_0.avi'
# Deleted: xclip_fight/train/No Fight/0vasozvJYvk_0.avi
# Deleted: xclip_fight/train/No Fight/fNy9LoED_0.avi
# Deleted: xclip_fight/train/Fight/l4gqDHx9_dI_2.avi
# Error deleting xclip_fight/train/No Fight/PTy2vx8Ejas_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/PTy2vx8Ejas_0.avi'
# Error deleting xclip_fight/train/Fight/UvLAudRA91Y_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/UvLAudRA91Y_1.avi'
# Error deleting xclip_fight/train/Fight/qmvilMkD57M_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/qmvilMkD57M_0.avi'
# Error deleting xclip_fight/train/Fight/kOp57sQKMPY_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/kOp57sQKMPY_0.avi'
# Error deleting xclip_fight/train/Fight/RTDSFDSA_675.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/RTDSFDSA_675.avi'
# Error deleting xclip_fight/train/No Fight/3pRrZ9TS_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/3pRrZ9TS_0.avi'
# Deleted: xclip_fight/train/No Fight/_fPfNbHM16M_1.avi
# Deleted: xclip_fight/train/No Fight/PqB7UvdW_0.avi
# Deleted: xclip_fight/train/Fight/NvYo6CS_i_A_0.avi
# Error deleting xclip_fight/train/No Fight/ykI6keNQ_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/ykI6keNQ_0.avi'
# Deleted: xclip_fight/train/Fight/1r0Wz04q_0.avi
# Deleted: xclip_fight/train/Fight/4yTlGiDoxBo_3.avi
# Deleted: xclip_fight/train/Fight/API3q8TBGu4_0.avi
# Deleted: xclip_fight/train/No Fight/a39igxDY_0.avi
# Error deleting xclip_fight/train/Fight/F7W6PQ3V3y8_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/F7W6PQ3V3y8_1.avi'
# Error deleting xclip_fight/train/Fight/YL-qwpTMjzk_2.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/YL-qwpTMjzk_2.avi'
# Error deleting xclip_fight/train/Fight/kOp57sQKMPY_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/kOp57sQKMPY_1.avi'
# Deleted: xclip_fight/train/Fight/a7gBQaAFEtw_2.avi
# Error deleting xclip_fight/train/Fight/JwTPruSFTjk_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/JwTPruSFTjk_1.avi'
# Error deleting xclip_fight/train/Fight/u1r8f71c_3.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/u1r8f71c_3.avi'
# Deleted: xclip_fight/train/Fight/5QqDgtwEQsI_0.avi
# Deleted: xclip_fight/train/Fight/MzcX84QCuE8_0.avi
# Error deleting xclip_fight/train/No Fight/_q5Nwh4Z6ao_1.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/_q5Nwh4Z6ao_1.avi'
# Error deleting xclip_fight/train/No Fight/ycOdxOJt_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/ycOdxOJt_0.avi'
# Error deleting xclip_fight/train/No Fight/4yTlGiDoxBo_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/No Fight/4yTlGiDoxBo_0.avi'
# Error deleting xclip_fight/train/Fight/s-jW4cyavW0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/train/Fight/s-jW4cyavW0_0.avi'
# Deleted: xclip_fight/train/Fight/OAfV0xPIhZw_4.avi
# Deleted: xclip_fight/train/No Fight/THqDidIr4Xs_1.avi
# Deleted: xclip_fight/val/No Fight/w6VytllR_0.avi
# Deleted: xclip_fight/val/Fight/48J5lk4QcpE_3.avi
# Error deleting xclip_fight/val/Fight/39BFeYnbu-I_4.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/39BFeYnbu-I_4.avi'
# Error deleting xclip_fight/val/Fight/v4dhdnsxiX4_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/v4dhdnsxiX4_2.avi'
# Error deleting xclip_fight/val/No Fight/TP6mtOzL_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/TP6mtOzL_0.avi'
# Deleted: xclip_fight/val/Fight/83d-16REC40_1.avi
# Error deleting xclip_fight/val/Fight/RTHTRS_707.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/RTHTRS_707.avi'
# Deleted: xclip_fight/val/No Fight/NWIc3Yat_0.avi
# Deleted: xclip_fight/val/No Fight/JOMXfA1R_0.avi
# Error deleting xclip_fight/val/Fight/YDOJvzChqSg_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/YDOJvzChqSg_1.avi'
# Error deleting xclip_fight/val/Fight/g-qjkePEXQA_3.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/g-qjkePEXQA_3.avi'
# Deleted: xclip_fight/val/No Fight/VtIQbKvy_0.avi
# Error deleting xclip_fight/val/Fight/I-QiUMPTWNE_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/I-QiUMPTWNE_2.avi'
# Deleted: xclip_fight/val/No Fight/LoQZojhn_0.avi
# Deleted: xclip_fight/val/Fight/trtrhrt_1040.avi
# Error deleting xclip_fight/val/No Fight/39BFeYnbu-I_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/39BFeYnbu-I_0.avi'
# Error deleting xclip_fight/val/Fight/TYRFDVD_1112.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/TYRFDVD_1112.avi'
# Deleted: xclip_fight/val/No Fight/PL8idmS7_0.avi
# Error deleting xclip_fight/val/No Fight/etyiEs3j8x8_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/etyiEs3j8x8_0.avi'
# Deleted: xclip_fight/val/Fight/I-QiUMPTWNE_0.avi
# Deleted: xclip_fight/val/Fight/A7FCl8G35Cs_1.avi
# Deleted: xclip_fight/val/Fight/YDOJvzChqSg_3.avi
# Error deleting xclip_fight/val/Fight/nVdn1krnTCQ_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/nVdn1krnTCQ_2.avi'
# Error deleting xclip_fight/val/Fight/0Ow4cotKOuw_4.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/0Ow4cotKOuw_4.avi'
# Deleted: xclip_fight/val/No Fight/cw8fPfUL_0.avi
# Error deleting xclip_fight/val/No Fight/I-QiUMPTWNE_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/I-QiUMPTWNE_2.avi'
# Deleted: xclip_fight/val/No Fight/qyRJeYN5_0.avi
# Error deleting xclip_fight/val/No Fight/O2rd3LTv_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/O2rd3LTv_0.avi'
# Error deleting xclip_fight/val/No Fight/nuf-d5GugL0_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/nuf-d5GugL0_2.avi'
# Deleted: xclip_fight/val/Fight/qaAclucigpY_2.avi
# Error deleting xclip_fight/val/Fight/zOqs7Oh9oDM_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/zOqs7Oh9oDM_0.avi'
# Error deleting xclip_fight/val/No Fight/tf_X7GtOGyE_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/tf_X7GtOGyE_2.avi'
# Error deleting xclip_fight/val/No Fight/YYCGcBuE_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/YYCGcBuE_0.avi'
# Error deleting xclip_fight/val/Fight/g6jdqkcdgqk_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/g6jdqkcdgqk_2.avi'
# Deleted: xclip_fight/val/Fight/JECBfnp2ZXc_1.avi
# Error deleting xclip_fight/val/No Fight/v4dhdnsxiX4_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/v4dhdnsxiX4_2.avi'
# Deleted: xclip_fight/val/No Fight/g8SVNUCm_0.avi
# Error deleting xclip_fight/val/Fight/7gLKFV5voOg_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/7gLKFV5voOg_0.avi'
# Error deleting xclip_fight/val/No Fight/VVQBImyG_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/VVQBImyG_0.avi'
# Error deleting xclip_fight/val/No Fight/iJ5Q1tar_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/iJ5Q1tar_0.avi'
# Error deleting xclip_fight/val/No Fight/8SmT9rE9_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/8SmT9rE9_0.avi'
# Error deleting xclip_fight/val/No Fight/1W8hsVvyKt4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/1W8hsVvyKt4_0.avi'
# Error deleting xclip_fight/val/Fight/nuf-d5GugL0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/nuf-d5GugL0_0.avi'
# Error deleting xclip_fight/val/Fight/trtrhrt_1053.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/trtrhrt_1053.avi'
# Error deleting xclip_fight/val/No Fight/Xcd0v-KhKL4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/Xcd0v-KhKL4_0.avi'
# Error deleting xclip_fight/val/Fight/tf_X7GtOGyE_3.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/tf_X7GtOGyE_3.avi'
# Error deleting xclip_fight/val/Fight/I-QiUMPTWNE_4.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/I-QiUMPTWNE_4.avi'
# Deleted: xclip_fight/val/Fight/fbtEhNq5a6E_0.avi
# Error deleting xclip_fight/val/No Fight/Ry5c1PbcIa0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/Ry5c1PbcIa0_0.avi'
# Deleted: xclip_fight/val/No Fight/CrBTbDcb_0.avi
# Deleted: xclip_fight/val/Fight/6Rl7q_kXYbg_5.avi
# Error deleting xclip_fight/val/No Fight/LtfqEsod_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/LtfqEsod_0.avi'
# Deleted: xclip_fight/val/No Fight/wMcODEtzJIA_0.avi
# Error deleting xclip_fight/val/No Fight/eb4Oant1_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/eb4Oant1_0.avi'
# Error deleting xclip_fight/val/No Fight/I-QiUMPTWNE_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/I-QiUMPTWNE_1.avi'
# Deleted: xclip_fight/val/No Fight/vXGRa5D6_0.avi
# Deleted: xclip_fight/val/Fight/RTHTRS_719.avi
# Deleted: xclip_fight/val/Fight/Q0v2MB0b_0.avi
# Error deleting xclip_fight/val/Fight/MxkTo5F-nvU_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/MxkTo5F-nvU_2.avi'
# Error deleting xclip_fight/val/Fight/OvDMIkTb4XU_3.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/OvDMIkTb4XU_3.avi'
# Deleted: xclip_fight/val/No Fight/tf_X7GtOGyE_0.avi
# Deleted: xclip_fight/val/No Fight/Bp3wCVsS_0.avi
# Deleted: xclip_fight/val/No Fight/Wq0BuA8GM84_0.avi
# Deleted: xclip_fight/val/No Fight/1W8hsVvyKt4_2.avi
# Error deleting xclip_fight/val/Fight/1Kbw1bUw_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/1Kbw1bUw_0.avi'
# Error deleting xclip_fight/val/Fight/RTHTRS_699.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/RTHTRS_699.avi'
# Deleted: xclip_fight/val/Fight/trtrhrt_1048.avi
# Error deleting xclip_fight/val/No Fight/v4dhdnsxiX4_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/v4dhdnsxiX4_0.avi'
# Error deleting xclip_fight/val/Fight/JECBfnp2ZXc_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/JECBfnp2ZXc_0.avi'
# Error deleting xclip_fight/val/No Fight/NnUOjff0_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/NnUOjff0_0.avi'
# Deleted: xclip_fight/val/No Fight/rJbh1niy_0.avi
# Error deleting xclip_fight/val/Fight/83d-16REC40_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/83d-16REC40_0.avi'
# Deleted: xclip_fight/val/No Fight/kApoSGPK_0.avi
# Error deleting xclip_fight/val/No Fight/mwuiYEBdkJs_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/mwuiYEBdkJs_1.avi'
# Deleted: xclip_fight/val/Fight/nuf-d5GugL0_1.avi
# Error deleting xclip_fight/val/No Fight/VTOPSZvF_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/VTOPSZvF_0.avi'
# Error deleting xclip_fight/val/No Fight/r0mVR4J6_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/r0mVR4J6_0.avi'
# Error deleting xclip_fight/val/Fight/g-qjkePEXQA_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/g-qjkePEXQA_0.avi'
# Error deleting xclip_fight/val/No Fight/DeCoZoey_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/DeCoZoey_0.avi'
# Deleted: xclip_fight/val/No Fight/rwg8hp5X_0.avi
# Error deleting xclip_fight/val/Fight/JECBfnp2ZXc_3.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/JECBfnp2ZXc_3.avi'
# Error deleting xclip_fight/val/Fight/nuf-d5GugL0_7.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/nuf-d5GugL0_7.avi'
# Error deleting xclip_fight/val/Fight/RIXaF_TkLlU_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/RIXaF_TkLlU_1.avi'
# Error deleting xclip_fight/val/Fight/y_vX9FtjLaQ_2.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/y_vX9FtjLaQ_2.avi'
# Error deleting xclip_fight/val/No Fight/QRJFLxqK_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/QRJFLxqK_0.avi'
# Error deleting xclip_fight/val/Fight/y_vX9FtjLaQ_4.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/y_vX9FtjLaQ_4.avi'
# Deleted: xclip_fight/val/No Fight/nVdn1krnTCQ_1.avi
# Error deleting xclip_fight/val/Fight/XM0NI7ZmwWM_3.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/XM0NI7ZmwWM_3.avi'
# Error deleting xclip_fight/val/No Fight/4p2iGvo8_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/4p2iGvo8_0.avi'
# Error deleting xclip_fight/val/No Fight/nuf-d5GugL0_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/nuf-d5GugL0_1.avi'
# Error deleting xclip_fight/val/No Fight/l82NDOvk_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/l82NDOvk_0.avi'
# Error deleting xclip_fight/val/Fight/RTHTRS_718.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/RTHTRS_718.avi'
# Error deleting xclip_fight/val/Fight/nuf-d5GugL0_6.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/nuf-d5GugL0_6.avi'
# Deleted: xclip_fight/val/Fight/g6jdqkcdgqk_4.avi
# Error deleting xclip_fight/val/No Fight/tf_X7GtOGyE_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/No Fight/tf_X7GtOGyE_1.avi'
# Error deleting xclip_fight/val/Fight/OvDMIkTb4XU_0.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/OvDMIkTb4XU_0.avi'
# Deleted: xclip_fight/val/No Fight/zsvJyWXp_0.avi
# Deleted: xclip_fight/val/Fight/nuf-d5GugL0_10.avi
# Deleted: xclip_fight/val/Fight/trtrhrt_1049.avi
# Error deleting xclip_fight/val/Fight/qaAclucigpY_1.avi: [Errno 2] No such file or directory: 'xclip_fight/val/Fight/qaAclucigpY_1.avi'

# %%
all_video_file_paths = (
    list(dataset_root_path.glob("train/*/*.avi"))
    + list(dataset_root_path.glob("val/*/*.avi"))
    + list(dataset_root_path.glob("test/*/*.avi"))
)
all_video_file_paths[:5]
# Out:
# [PosixPath('xclip_fight/train/Fight/3CQi0ZCCHvc_2.avi'),
#  PosixPath('xclip_fight/train/Fight/mRqg-WXiR7Q_3.avi'),
#  PosixPath('xclip_fight/train/Fight/truutrdf_1082.avi'),
#  PosixPath('xclip_fight/train/Fight/jmZqmYnH_0.avi'),
#  PosixPath('xclip_fight/train/Fight/wetyh_1206.avi')]

# %% [markdown]
# Next up, we derive the set of labels we have in the dataset. Let's also create two dictionaries that'll be helpful when initializing the model:
#
# * `label2id`: maps the class names to integers.
# * `id2label`: maps the integers to class names.

# %%
all_video_file_paths

# %%
class_labels = sorted({str(path).split("/")[2] for path in all_video_file_paths})
label2id = {label: i for i, label in enumerate(class_labels)}
id2label = {i: label for label, i in label2id.items()}
print(f"Unique classes: {list(label2id.keys())}.")
# Out:
# Unique classes: ['Fight', 'No Fight'].

# %% [markdown]
# We've got 10 unique classes. For each class we have 30 videos in the training set.

# %% [markdown]
# ### Loading the model

# %% [markdown]
# In the next cell, we initialize a video classification model where the encoder is initialized with the pre-trained parameters and the classification head is randomly initialized. We also initialize the feature extractor associated to the model. This will come in handy during writing the preprocessing pipeline for our dataset.

# %%
from transformers import VideoMAEImageProcessor, VideoMAEForVideoClassification


image_processor = VideoMAEImageProcessor.from_pretrained(model_ckpt)
model = VideoMAEForVideoClassification.from_pretrained(
    model_ckpt,
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes=True,  # provide this in case you're planning to fine-tune an already fine-tuned checkpoint
)
# Out:
# preprocessor_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/377M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of VideoMAEForVideoClassification were not initialized from the model checkpoint at MCG-NJU/videomae-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The warning is telling us we are throwing away some weights (e.g. the weights and bias of the `classifier` layer) and randomly initializing some other (the weights and bias of a new `classifier` layer). This is expected in this case, because we are adding a new head for which we don't have pretrained weights, so the library warns us we should fine-tune this model before using it for inference, which is exactly what we are going to do.

# %% [markdown]
# **Note** that [this checkpoint](https://huggingface.co/MCG-NJU/videomae-base-finetuned-kinetics) leads to better performance on this task as the checkpoint was obtained fine-tuning on a similar downstream task having considerable domain overlap. You can check out [this checkpoint](https://huggingface.co/sayakpaul/videomae-base-finetuned-kinetics-finetuned-ucf101-subset) which was obtained by fine-tuning `MCG-NJU/videomae-base-finetuned-kinetics` and it obtains much better performance.

# %% [markdown]
# ### Constructing the datasets for training

# %% [markdown]
# For preprocessing the videos, we'll leverage the [PyTorch Video library](https://pytorchvideo.org/). We start by importing the dependencies we need.

# %%
import pytorchvideo.data

from pytorchvideo.transforms import (
    ApplyTransformToKey,
    Normalize,
    RandomShortSideScale,
    RemoveKey,
    ShortSideScale,
    UniformTemporalSubsample,
)

from torchvision.transforms import (
    Compose,
    Lambda,
    RandomCrop,
    RandomHorizontalFlip,
    Resize,
)

# %% [markdown]
# For the training dataset transformations, we use a combination of uniform temporal subsampling, pixel normalization, random cropping, and random horizontal flipping. For the validation and evaluation dataset transformations, we keep the transformation chain the same except for random cropping and horizontal flipping. To learn more about the details of these transformations check out the [official documentation of PyTorch Video](https://pytorchvideo.org).
#
# We'll use the `image_processor` associated with the pre-trained model to obtain the following information:
#
# * Image mean and standard deviation with which the video frame pixels will be normalized.
# * Spatial resolution to which the video frames will be resized.

# %%
import os

mean = image_processor.image_mean
std = image_processor.image_std
if "shortest_edge" in image_processor.size:
    height = width = image_processor.size["shortest_edge"]
else:
    height = image_processor.size["height"]
    width = image_processor.size["width"]
resize_to = (height, width)

num_frames_to_sample = model.config.num_frames
sample_rate = 4
fps = 30
clip_duration = num_frames_to_sample * sample_rate / fps


# Training dataset transformations.
train_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    RandomShortSideScale(min_size=256, max_size=320),
                    RandomCrop(resize_to),
                    RandomHorizontalFlip(p=0.5),
                ]
            ),
        ),
    ]
)

# Training dataset.
train_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "train"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("random", clip_duration),
    decode_audio=False,
    transform=train_transform,

)

# Validation and evaluation datasets' transformations.
val_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    Resize(resize_to),
                ]
            ),
        ),
    ]
)

# Validation and evaluation datasets.
val_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "val"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("uniform", clip_duration),
    decode_audio=False,
    transform=val_transform,
)

test_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "val"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("uniform", clip_duration),
    decode_audio=False,
    transform=val_transform,
)

# %% [markdown]
# **Note**: The above dataset pipelines are taken from the [official PyTorch Video example](https://pytorchvideo.org/docs/tutorial_classification#dataset). We're using the [`pytorchvideo.data.Ucf101()`](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html#pytorchvideo.data.Ucf101) function because it's tailored for the UCF-101 dataset. Under the hood, it returns a [`pytorchvideo.data.labeled_video_dataset.LabeledVideoDataset`](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html#pytorchvideo.data.LabeledVideoDataset) object. `LabeledVideoDataset` class is the base class for all things video in the PyTorch Video dataset. So, if you wanted to use a custom dataset not supported off-the-shelf by PyTorch Video, you can extend the `LabeledVideoDataset` class accordingly. Refer to the `data` API [documentation to](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html) learn more. Also, if your dataset follows a similar structure (as shown above), then using the `pytorchvideo.data.Ucf101()` should work just fine.

# %%
# We can access the `num_videos` argument to know the number of videos we have in the
# dataset.
train_dataset.num_videos, val_dataset.num_videos, test_dataset.num_videos
# Out:
# (507, 134, 134)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Let's now take a preprocessed video from the dataset and investigate it.

# %%
sample_video = next(iter(train_dataset))
sample_video.keys()
# Out:
# dict_keys(['video', 'video_name', 'video_index', 'clip_index', 'aug_index', 'label'])

# %%
def investigate_video(sample_video):
    """Utility to investigate the keys present in a single video sample."""
    for k in sample_video:
        if k == "video":
            print(k, sample_video["video"].shape)
        else:
            print(k, sample_video[k])

    print(f"Video label: {id2label[sample_video[k]]}")


investigate_video(sample_video)
# Out:
# video torch.Size([3, 16, 224, 224])
# video_name p9d6QmKh_0.avi
# video_index 468
# clip_index 0
# aug_index 0
# label 1
# Video label: No Fight

# %% [markdown]
# We can also visualize the preprocessed videos for easier debugging.

# %%
import imageio
import numpy as np
from IPython.display import Image


def unnormalize_img(img):
    """Un-normalizes the image pixels."""
    img = (img * std) + mean
    img = (img * 255).astype("uint8")
    return img.clip(0, 255)


def create_gif(video_tensor, filename="sample.gif"):
    """Prepares a GIF from a video tensor.

    The video tensor is expected to have the following shape:
    (num_frames, num_channels, height, width).
    """
    frames = []
    for video_frame in video_tensor:
        frame_unnormalized = unnormalize_img(video_frame.permute(1, 2, 0).numpy())
        frames.append(frame_unnormalized)
    kargs = {"duration": 0.25}
    imageio.mimsave(filename, frames, "GIF", **kargs)
    return filename


def display_gif(video_tensor, gif_name="sample.gif"):
    """Prepares and displays a GIF from a video tensor."""
    video_tensor = video_tensor.permute(1, 0, 2, 3)
    gif_filename = create_gif(video_tensor, gif_name)
    return Image(filename=gif_filename)

# %%
video_tensor = sample_video["video"]
display_gif(video_tensor)

# %% [markdown]
# ### Training the model

# %% [markdown]
# We'll leverage [`Trainer`](https://huggingface.co/docs/transformers/main_classes/trainer) from  🤗 Transformers for training the model. To instantiate a `Trainer`, we will need to define the training configuration and an evaluation metric. The most important is the [`TrainingArguments`](https://huggingface.co/transformers/main_classes/trainer.html#transformers.TrainingArguments), which is a class that contains all the attributes to configure the training. It requires an output folder name, which will be used to save the checkpoints of the model. It also helps sync all the information in the model repository on 🤗 Hub.
#
# Most of the training arguments are pretty self-explanatory, but one that is quite important here is `remove_unused_columns=False`. This one will drop any features not used by the model's call function. By default it's `True` because usually it's ideal to drop unused feature columns, making it easier to unpack inputs into the model's call function. But, in our case, we need the unused features ('video' in particular) in order to create `pixel_values` (which is a mandatory key our model expects in its inputs).

# %%
from transformers import TrainingArguments, Trainer
model_name = model_ckpt.split("/")[-1]
new_model_name = f"{model_name}-finetuned-fight-nofight-subset2"
num_epochs = 2
batch_size = 4

args = TrainingArguments(
    new_model_name,
    remove_unused_columns=False,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    push_to_hub=True,
    fp16=True,
    torch_compile=True,

    max_steps=(train_dataset.num_videos // batch_size) * num_epochs,
)
# Out:
# The speedups for torchdynamo mostly come wih GPU Ampere or higher and which is not detected here.

# %% [markdown]
# There's no need to define `max_steps` when instantiating `TrainingArguments`. Since the dataset returned by `pytorchvideo.data.Ucf101()` doesn't implement the `__len__()` method we had to specify `max_steps`.

# %% [markdown]
# Next, we need to define a function for how to compute the metrics from the predictions, which will just use the `metric` we'll load now. The only preprocessing we have to do is to take the argmax of our predicted logits:

# %%
# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions."""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %% [markdown]
# **A note on evaluation**:
#
# In the [VideoMAE paper](https://arxiv.org/abs/2203.12602), the authors use the following evaluation strategy. They evaluate the model on several clips from test videos and apply different crops to those clips and report the aggregate score. However, in the interest of simplicity and brevity, we don't consider that in this tutorial.

# %% [markdown]
# We also define a `collate_fn`, which will be used to batch examples together.
# Each batch consists of 2 keys, namely `pixel_values` and `labels`.

# %%
import torch


def collate_fn(examples):
    """The collation function to be used by `Trainer` to prepare data batches."""
    # permute to (num_frames, num_channels, height, width)
    pixel_values = torch.stack(
        [example["video"].permute(1, 0, 2, 3) for example in examples]
    )
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %% [markdown]
# Then we just need to pass all of this along with our datasets to the `Trainer`:

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)

# %% [markdown]
# You might wonder why we pass along the `image_processor` as a tokenizer when we already preprocessed our data. This is only to make sure the feature extractor configuration file (stored as JSON) will also be uploaded to the repo on the hub.

# %% [markdown]
# Now we can finetune our model by calling the `train` method:

# %%
pip install triton

# %%
train_results = trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240131_094031-l1a6b1qu</code>
# Syncing run <strong><a href='https://wandb.ai/dumbal/huggingface/runs/l1a6b1qu' target="_blank">easy-pine-20</a></strong> to <a href='https://wandb.ai/dumbal/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbal/huggingface' target="_blank">https://wandb.ai/dumbal/huggingface</a>
#  View run at <a href='https://wandb.ai/dumbal/huggingface/runs/l1a6b1qu' target="_blank">https://wandb.ai/dumbal/huggingface/runs/l1a6b1qu</a>
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='252' max='252' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [252/252 39:18, Epoch 3/9223372036854775807]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.514500</td>
#       <td>0.784473</td>
#       <td>0.507463</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.607000</td>
#       <td>0.688600</td>
#       <td>0.634328</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.398600</td>
#       <td>0.510551</td>
#       <td>0.746269</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.363200</td>
#       <td>0.740821</td>
#       <td>0.671642</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
trainer.evaluate(test_dataset)
# Out:
# {'eval_loss': 0.5190202593803406,
#  'eval_accuracy': 0.7434944237918215,
#  'eval_runtime': 173.952,
#  'eval_samples_per_second': 1.546,
#  'eval_steps_per_second': 0.195,
#  'epoch': 3.24}

# %%
test_dataset

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
trainer.save_model()
test_results = trainer.evaluate(test_dataset)
trainer.log_metrics("test", test_results)
trainer.save_metrics("test", test_results)
trainer.save_state()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 2
#       1 trainer.save_model()
# ----> 2 test_results = trainer.evaluate(test_dataset)
#       3 trainer.log_metrics("test", test_results)
#       4 trainer.save_metrics("test", test_results)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:3081, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3078 # memory metrics - must set up as early as possible
#    3079 self._memory_tracker.start()
# -> 3081 eval_dataloader = self.get_eval_dataloader(eval_dataset)
#    3082 start_time = time.time()
#    3084 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:867, in Trainer.get_eval_dataloader(self, eval_dataset)
#     864     dataloader_params["sampler"] = self._get_eval_sampler(eval_dataset)
#     865     dataloader_params["drop_last"] = self.args.dataloader_drop_last
# --> 867 return self.accelerator.prepare(DataLoader(eval_dataset, **dataloader_params))
#
# File /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:1183, in Accelerator.prepare(self, device_placement, *args)
#    1172     if (
#    1173         isinstance(obj, torch.nn.Module)
#    1174         and self.verify_device_map(obj)
#    1175         and self.distributed_type != DistributedType.NO
#    1176         and os.environ.get("ACCELERATE_BYPASS_DEVICE_MAP", "false") != "true"
#    1177     ):
#    1178         raise ValueError(
#    1179             "You can't train a model that has been loaded with `device_map='auto'` in any distributed mode."
#    1180             " Please rerun your script specifying `--num_processes=1` or by launching with `python {{myscript.py}}`."
#    1181         )
# -> 1183 if self.distributed_type == DistributedType.DEEPSPEED:
#    1184     model_count = 0
#    1185     for obj in args:
#
# File /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:495, in Accelerator.distributed_type(self)
#     493 @property
#     494 def distributed_type(self):
# --> 495     return self.state.distributed_type
#
# AttributeError: 'AcceleratorState' object has no attribute 'distributed_type'

# %% [markdown]
# You can now upload the result of the training to the Hub, just execute this instruction (note that the Trainer will automatically create a model card as well as Tensorboard logs - see the "Training metrics" tab - amazing isn't it?):

# %%
trainer.push_to_hub()
# Out:
# CommitInfo(commit_url='https://huggingface.co/archit11/videomae-base-finetuned-fight-nofight-subset2/commit/f6e4fdb0457c573cded3a98eb18f132f881e0c66', commit_message='End of training', commit_description='', oid='f6e4fdb0457c573cded3a98eb18f132f881e0c66', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# Now that our model is trained, let's use it to run inference on a video from `test_dataset`.

# %% [markdown]
# ## Inference

# %% [markdown]
# Let's load the trained model checkpoint and fetch a video from `test_dataset`.

# %%
trained_model = VideoMAEForVideoClassification.from_pretrained(new_model_name)

# %%
sample_test_video = next(iter(test_dataset))
investigate_video(sample_test_video)

# %% [markdown]
# We then prepare the video as a `torch.Tensor` and run inference.

# %%
def run_inference(model, video):
    """Utility to run inference given a model and test video.

    The video is assumed to be preprocessed already.
    """
    # (num_frames, num_channels, height, width)
    perumuted_sample_test_video = video.permute(1, 0, 2, 3)

    inputs = {
        "pixel_values": perumuted_sample_test_video.unsqueeze(0),
        "labels": torch.tensor(
            [sample_test_video["label"]]
        ),  # this can be skipped if you don't have labels available.
    }
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    model = model.to(device)

    # forward pass
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    return logits

# %%
logits = run_inference(trained_model, sample_test_video["video"])

# %% [markdown]
# We can now check if the model got the prediction right.

# %%
display_gif(sample_test_video["video"])

# %%
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
